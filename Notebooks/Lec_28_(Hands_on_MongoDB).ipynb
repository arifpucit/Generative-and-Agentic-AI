# %% [markdown]
#  <img align="left" width="75" height="75"  src="https://upload.wikimedia.org/wikipedia/en/c/c8/University_of_the_Punjab_logo.png">
#
# <h1 align="center">Department of Data Science</h1>
#
# ---
# <h3><div align="right">Instructor: Muhammad Arif Butt, Ph.D.</div></h3>

# %% [markdown]
# <h1 align="center">Lec-28: Hands-on <b>MongoDB</b></h1>

# %% [markdown]
# # Learning agenda of this notebook
#
# 1. Overview of MongoDB
# 2. Setting-up the Lab Environment for MongoDB
#     - Local Installation: MongoDB Server (`mongod`), Command Line Client (`mongosh`), and a GUI tool (`mongodb-compass`)
#     - Hands-On Practice of Connecting MongoDB Server via `mongosh`
#     - Hands-On Practice of Connecting MongoDB Server via `MongoDB compass`
# 3. Hands-On Practice of Accessing MongoDB via `mongosh` and `MongoDB compass`
#     - Creating users
#     - Creating/Deleting/Renaming Databases and Collections
#     - MongoDB Query Language (MQL) - Insert Operations using `mongosh`
#     - MongoDB Query Language (MQL) - Read Operations using `mongosh`
#     - MongoDB Query Language (MQL) - Update Operations using `mongosh`
#     - MongoDB Query Language (MQL) - Delete Operations using `mongosh`
#     - Indexing in MongoDB using `mongosh`
# 4. Hands-On Practice of Accessing MongoDB via Python's `pymongo` Module
#     - MongoDB Query Language (MQL) - Create Operations using `pymongo`
#     - MongoDB Query Language (MQL) - Insert Operations using `pymongo`
#     - MongoDB Query Language (MQL) - Read Operations  using `pymongo`
#     - MongoDB Query Language (MQL) - Update Operations  using `pymongo`
#     - MongoDB Query Language (MQL) - Delete Operations  using `pymongo`
#     - Indexing in MongoDB using `pymongo`
# 5. Hands-On Practice of Connecting Cloud-Hosted MongoDB via MongoDB Atlas

# %% [markdown]
# # <span style='background :lightgreen' >1. An Overview of MongoDB</span>
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">MongoDB is a NoSQL, document-oriented database that stores data in flexible, JSON-like documents</div></h3>
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">MongoDB = Schema-less, document-based, flexible → perfect for modern apps</div></h3>
#
#
#
#
# <table style="width: 100%; border-collapse: collapse;">
#   <tr>
#    <td style="text-align: center; padding: 10px;">
#       <img src="../images/mongoDB_logo.png" style="width: 400px"; border: 1px solid #ccc;">
#     </td>
#       <td style="padding: 20px; vertical-align: top; font-size: 15px; line-height: 1.6;">
#       <h2>Basic Units</h2>
#       <h3>Database:</h3>
#       <ul>
#         <li>A container for collections</li>
#       </ul>
#       <h3>Collection:</h3>
#       <ul>
#         <li>A group of MongoDB documents (equivalent to tables in SQL).</li>
#       </ul>
#       <h3>Document:</h3>
#       <ul>
#         <li>JSON-like structure having dynamic schema (flexible fields).</li>
#       </ul>
#     </td>
#     <td style="text-align: center; padding: 10px;">
#       <img src="../images/architecture.png"  style="width: 600px"; border: 1px solid #ccc;">
#     </td>
#   </tr>
# </table>
#
#
# ## a. Comparison of SQL, NoSQL, and Vector Databases
#
#
# | Feature | SQL Database (Relational) | NoSQL Database (Non-Relational) | Vector Database (AI-Native) |
# |---------|---------------------------|----------------------------------|------------------------------|
# | **Data Structure** | Structured tables with predefined schemas (rows and columns) | Flexible: documents, key-value pairs, graphs, or wide-column stores | High-dimensional vectors (embeddings) with optional metadata |
# | **Data Type** | Text, numbers, dates, booleans stored in fixed columns | JSON/BSON documents, nested objects, arrays, varied data types | Numerical arrays (vectors) representing semantic meaning of data |
# | **Schema** | Strict schema required before inserting data | Schema-less or dynamic schema (flexible structure) | Minimal schema: vectors + optional metadata (schema-flexible) |
# | **Relationships** | Strong relationships using foreign keys and JOINs | Embedded documents or references (denormalization preferred) | Weak relationships; focuses on content similarity rather than explicit links |
# | **Scalability** | Vertical scaling (bigger server); horizontal scaling is complex | Horizontal scaling (across  servers/shards); designed for distributed systems | Horizontal scaling; optimized for high-dimensional vector operations |
# | **ACID Compliance** | Strong ACID guarantees (Atomicity, Consistency, Isolation, Durability) | Often eventual consistency; some offer ACID for single documents | Varies; typically prioritizes performance over strict ACID |
# | **Query Language** | SQL (Structured Query Language) | Varies by database: MongoDB Query Language, CQL, Cypher, etc. | Similarity search APIs, distance metrics (cosine, euclidean, dot product) |
# | **Query Style** | • Exact match queries<br>• Filtering, sorting, joining<br>• Example: `WHERE name = 'Ali'` | • Document/field queries<br>• Range queries, text search<br>• Example: `{name: "Ali", age: {$gt: 25}}` | • Semantic similarity search<br>• Nearest neighbor search<br>• Example: "Find documents similar to 'machine learning'" |
# | **Query Example** | `SELECT * FROM users WHERE age > 25 AND city = 'Lahore'` | `db.users.find({age: {$gt: 25}, city: "Lahore"})` | `collection.query(query_texts=["young professionals in Lahore"])` |
# | **Primary Use Cases** | • Financial transactions<br>• E-commerce systems<br>• Inventory management<br>• Banking applications<br>• HR systems | • Content management<br>• Real-time analytics<br>• Social media platforms<br>• IoT data storage<br>• Mobile applications | • Semantic search engines<br>• AI chatbots & RAG systems<br>• Recommendation systems<br>• Image/video similarity search<br>• Anomaly detection |
# | **Popular Examples** | • MySQL<br>• PostgreSQL<br>• Oracle Database<br>• Microsoft SQL Server<br>• SQLite<br>• MariaDB | **Document:** MongoDB, CouchDB<br>**Key-Value:** Redis, DynamoDB<br>**Column:** Cassandra, HBase<br>**Graph:** Neo4j, ArangoDB | • ChromaDB<br>• Pinecone<br>• Weaviate<br>• Milvus<br>• Qdrant<br>• FAISS (by Meta) |

# %% [markdown]
# # <span style='background :lightgreen' >2. Setting-up the Lab Environment for MongoDB</span>
# ## a. Local Installation: MongoDB Server (`mongod`), Command Line Client (`mongosh`), and a GUI tool (`mongodb-compass`)
# - https://www.mongodb.com/docs/manual/
# - Perform the installation of MongoDB Community Edition for your respective OS. Mine is MacOS so following are the commands for installing them using `brew`:
# ```bash
# # Make sure Homebrew is installed
# !brew --version
# # Install MongoDB Server
# !brew tap mongodb/brew
# !brew install mongodb-community
# # Install Command line tool for MongoDB
# !brew install mongosh
# # Install GUI client tool for MongoDB. Compass is similar to MySQL Workbench or Squel Ace that runs locally on your computer and can connect to any MongoDB server (local, remote, Atlas). Used to browse collections and documents visually, has a visual query builder, can analyze schema and performance, can create indexes, and can import/export data.
# !brew install --cask mongodb-compass
# # Search for any mongo related packages installed via brew
# brew list | grep mongo
# # Start MongoDB as a service (runs in background, starts on login) at default port 27017
# !brew services [start stop restart] mongodb-community
# # check if MongoDB is running services
# !brew services list
# # Check if MongoDB is listening on port 27017
# lsof -i :27017
# # Check MongoDB version
# mongod --version
# mongosh --version
# ```

# %% [markdown]
# ## b. Hands-On Practice of Connecting MongoDB Server via `mongosh`
#
# <div align="center">
#   <img width="1400" src="../images/shell.png">
# </div>
#
# ### What is mongosh:
# - `mongosh` (MongoDB Shell) is a command-line interface tool that allows you to interact with MongoDB databases through text commands
# - It provides a JavaScript-based environment for running queries, managing databases, and performing administrative tasks
# ### Authentication in MongoDB:
# - When you install MongoDB via Homebrew, it has **no default users** and authentication is **disabled by default**
# - Therefore, you can connect without any username/password
# ### How to connect:
# - Open a new terminal window
# - Type the command: `mongosh`
# - Press Enter to connect to MongoDB running on `localhost:27017`
# - You'll see the prompt `test>` indicating you're connected to the default **test** database
# - To exit mongosh, use the command: `exit` or `quit()`
# ### Default databases in MongoDB:
# - **admin:** The authentication and authorization database where administrative users and system-wide commands are stored
# - **config:** Stores metadata and configuration settings for sharded clusters (routing information, chunk distribution, etc.)
# - **local:** Contains replication-specific data and is never replicated across replica set members; each server has its own local database
# ### What you can do in mongosh:
# - **Create and switch databases:** Use `use databaseName` to create or switch to a database
# - **Run queries:** Execute find, insert, update, and delete operations on collections
# - **Manage collections:** Create, drop, and rename collections
# - **User management:** Create users, assign roles, and manage permissions
# - **Run JavaScript:** Execute JavaScript code and functions directly in the shell
# - **Administrative tasks:** Monitor server status, manage indexes, and perform backups

# %% [markdown]
# ## c. Hands-On Practice of Connecting MongoDB Server via `MongoDB compass`
#
# <div align="center">
#   <img width="1400" src="../images/compass1.png">
# </div>
#
# ### What is MongoDB Compass:
# - MongoDB Compass is a graphical user interface (GUI) tool that provides a visual alternative to the command-line shell
# - It allows you to explore and interact with your databases through an intuitive visual interface without writing commands
# ### How to launch:
# - Open MongoDB Compass from the **Applications** menu, or by running **Spotlight/Alfred**
# - Alternatively, from the terminal run: `open -a "MongoDB Compass"`
# ### How to connect:
# - When MongoDB Compass opens (for the first time), you'll see a connection screen
# - The default connection string should already be filled in: `mongodb://localhost:27017`
# - Click the **Connect** button to establish the connection
# - **Tip:** Save this connection with a name (like "Local MongoDB") for quick access in the future
# - You're now connected and can visually browse your databases!
# ### What you can do in Compass:
# - **Browse databases and collections:** Visually explore your data structure and documents with a tree view
# - **Run queries:** Use the visual query builder to filter and search documents without writing code
# - **Insert/Update/Delete:** Modify documents directly through forms and editors in the GUI
# - **Create indexes:** Optimize query performance with visual index management and recommendations
# - **Analyze schema:** Understand document structure, data types, and value distributions across your collections
# - **View performance:** Monitor query execution plans, performance metrics, and database statistics
# - **Import/Export data:** Easily import JSON/CSV files or export collections visually
# - **Aggregation pipeline builder:** Create complex aggregation queries using a visual drag-and-drop interface

# %% [markdown]
# # <span style='background :lightgreen' >3. Hands-On Practice of Accessing MongoDB via `mongosh` and `MongoDB compass`</span>
#
# ```
# 📦 book_store
# │
# ├── 📁 books (A collection that stores information about individual books)
# │  ├── 📄 book_101 – { title: "MongoDB Basics", author: "Dr. Arif", price: 25 }
# │  ├── 📄 book_102 – { title: "Python for All", author: "Dr. Jamil", price: 30 }
# │  └── 📄 book_103 – { title: "AI in Action", author: "Dr. Rauf", price: 40 }
# │
# ├── 📁 customers (A collection that contains customer details)
# │  ├── 📄 customer_1 – { name: "Shaikh Shahid", age: 45, email: "shahid@gmail.com" }
# │  ├── 📄 customer_2 – { name: "Waqas Aslam", age: 55, email: "waqas@yahoo.com" }
# │  └── 📄 customer_3 – { name: "Umer Khan", age: 30, email: "umer@outlook.com" }
# │
# ├── 📁 orders (A collection, where each order references a customer and one or more books, along with the total amount)
# │  ├── 📄 order_1 – { customer: "Waqas Aslam", books: ["book_101", "book_103"], total: 65 }
# │  └── 📄 order_2 – { customer: "Shaikh Shahid", books: ["book_102"], total: 30 }
# │
# └── 📁 reviews (A collection that links reviews to specific books, including a rating and optional comment)
#    ├── 📄 review_1 – { book: "book_101", rating: 5, comment: "Excellent for beginners!" }
#    └── 📄 review_2 – { book: "book_103", rating: 4, comment: "Good coverage of concepts." }
# ```
# >- Documents are stored as BSON (Binary JSON)
# >- Each document can have a unique set of fields, and fields are not required to exist in every document. This flexibility makes it easy to evolve your data model as requirements change.
# >- However: For consistency and ease of querying, it’s often beneficial for documents in a collection to follow a consistent structure.
# You can optionally enforce structure by using schema validation in MongoDB, but by default, it is not enforced.

# %%
# Thanks to my students, who are also my teachers
from IPython.display import Video

Video("../images/CRUD.mp4", width=800, height=450)
# Out:
# <video src="../images/CRUD.mp4" controls  width="800"  height="450">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## a. Creating users
# #### Common Roles in MongoDB
# ```javascript
# // Database User Roles:
# - read              // Read data from all non-system collections
# - readWrite         // Read and write data to all non-system collections
# // Database Administration Roles:
# - dbAdmin           // Perform administrative tasks
# - userAdmin         // Create and modify roles and users
# - dbOwner           // Perform any administrative action
# // Cluster Administration Roles:
# - clusterAdmin      // Manage and monitor the cluster
# - clusterManager    // Manage and monitor operations
# - clusterMonitor    // Read-only access to monitoring tools
# // All-Database Roles:
# - readAnyDatabase   // Read data from all databases
# - readWriteAnyDatabase  // Read and write to all databases
# - userAdminAnyDatabase  // Manage users on all databases
# - dbAdminAnyDatabase    // Database admin on all databases
# // Superuser Roles:
# - root              // Complete access to all resources
# ```
# #### Creating a user arif with root Privileges
# ```bash
# # Create a user with all privileges on all databases inside the admin database
# $ mongosh
# test> use admin
# test> db.createUser({user: "arif", pwd: "pass", roles: [ {"root", db: "admin"}]})
# test> db.createUser({user: "arif", pwd: "123456", roles: [ { role: "root", db: "admin" } ]})
#
# # Create user for a specific database who can just readWrite it
# test> use myDatabase
# test> db.createUser({user: "myAppUser", pwd: "password123", roles: [ {role: "readWrite", db: "myDatabase"}]})
# ```
# - Now, you can connect with authentication
# ```bash
# # Connect with authentication
# $ mongosh "mongodb://arif:pass@localhost:27017"
# $ mongosh --host localhost --port 27017 --username arif --password
# ```
# - You can manually enable authentication by opening the  `/opt/homebrew/etc/mongod.conf` file in some editor, and adding following LOCs and then restarting the service using `brew services restart mongodb-community` command.
# ```bash
# security:
#   authorization: enabled
# ```

# %% [markdown]
# ## b. Creating/Deleting/Renaming Databases and Collections
# - When you login into mongoDB, it automatically creates a database named test having no collections for you to work on.
# ```bash
# test> show dbs                          # show existing databases
# test> use book_store_A                  # Create/switch to a database (creates if doesn't exist)
# book_store_A> db                        # Get database name
# book_store_A> db.getName()              # Get database name
# book_store_A> db.dropDatabase()         # Drop/delete current database
#
# test> use book_store_A                       # Create/switch to a database (creates if doesn't exist)
# book_store_A> db.createCollection("books")   # Collections are created automatically on first insert, however, you can create a collection explicitly as well
# book_store_A> db.createCollection("reviews")
# book_store_A> db.createCollection("customers")
# book_store_A> db.createCollection("orders")
# book_store_A> show collections/tables                # Show all collections in current database
#
# book_store_A> db.books.drop()                        # Drop/delete the books collection from database
# book_store_A> db.createCollection("books")           # Create the books collection again
# book_store_A> db.customers.renameCollection("cust")  # Rename customers to cust
# book_store_A> db.cust.renameCollection("customers")  # Rename back to customers
#
#
# book_store_A> exit               # Exit MongoDB shell, Do not work in mongosh of Compass
# book_store_A> quit()             # Exit MongoDB shell
# ```

# %% [markdown]
# ## c. MongoDB Query Language (MQL)  - Insert Operations using `mongosh`
# - MongoDB uses MQL (MongoDB Query Language) to perform insert operations through shell methods like `insertOne()` and `insertMany()`.
# - These methods allow you to add new documents into a collection in a flexible, schema-less JSON format (internally stored as BSON).
# ```javascript
# db.collection.insertOne(document)                      // Inserts a single document and returns an object containing the newly inserted document’s _id
# db.collection.insertMany([document1, document2, ...])  // Inserts multiple documents and returns an object with an array of all inserted IDs
# ```
# - The document is a JSON object enclosed in curly braces { }, representing the data to be inserted into the collection.
# - Each inserted document automatically gets a unique _id field (ObjectId) if not provided.

# %% [markdown]
# ```bash
# #  ===== Insert documents inside books collection =====
# book_store_A> db.books.insertOne({_id: "book_101", title: "MongoDB Basics", author: "Dr. Arif", price: 25})
# book_store_A> db.books.insertMany([
#                           { _id: "book_102", title: "Python for All", author: "Dr. Jamil", price: 30 },
#                           { _id: "book_103", title: "AI in Action", author: "Dr. Rauf", price: 40 }
#                 ])
# book_store_A> db.books.find()
# book_store_A> db.books.stats().count       # Count of documents inside the collection
# book_store_A> db.books.stats().size        # Total size (in bytes) of all the actual data documents stored in the collection
# book_store_A> db.books.stats().storageSize # Actual disk space is reserved for collection
# ```

# %% [markdown]
# ```bash
# #  ===== Insert documents inside reviews collection =====
# book_store_A> db.reviews.insertMany([
#                           { _id: "review_1", book: "book_101", rating: 5, comment: "Excellent for beginners!" },
#                           { _id: "review_2", book: "book_103", rating: 4, comment: "Good coverage of concepts." }
#                 ])
# book_store_A> db.reviews.find()
# ```

# %% [markdown]
# ```bash
# #  ===== Insert documents inside customers collection =====
# book_store_A> db.customers.insertMany([
#                         { _id: "customer_1", name: "Shaikh Shahid", age: 45, email: "shahid@gmail.com" },
#                         { _id: "customer_2", name: "Waqas Aslam", age: 55, email: "waqas@yahoo.com" },
#                         { _id: "customer_3", name: "Umer Khan", age: 30, email: "umer@outlook.com" }
#                 ])
# book_store_A> db.customers.find()
# ```

# %% [markdown]
# ```bash
# #  ===== Insert documents inside orders collection =====
# book_store_A> db.orders.insertMany([
#                         { _id: "order_1", customer: "Tipu Sultan", books: ["book_101", "book_103"], total: 65 },
#                         { _id: "order_2", customer: "Salah ud Din", books: ["book_102"], total: 30 }
#                 ])
# book_store_A> db.orders.find()
# ```

# %% [markdown]
# ###  Datatypes in MongoDB
#
# | BSON Type | Example Value | Example Document | Description |
# |-----------|---------------|------------------|-------------|
# | **String** | `"Hello World"` | `{ name: "Ali", email: "ali@example.com" }` | Text data, must be UTF-8 encoded |
# | **Integer (32-bit)** | `NumberInt(123)` | `{ age: NumberInt(25), score: NumberInt(95) }` | 32-bit integer (-2,147,483,648 to 2,147,483,647) |
# | **Integer (64-bit)** | `NumberLong(123)` | `{ population: NumberLong(220892340) }` | 64-bit integer for larger numbers |
# | **Double** | `123.45` | `{ temperature: 36.5, weight: 65.8 }` | 64-bit floating point number (default for numbers) |
# | **Decimal128** | `NumberDecimal("19.99")` | `{ product: "Laptop", price: NumberDecimal("999.99") }` | High-precision decimal (for currency, financial data) |
# | **Boolean** | `true` / `false` | `{ isActive: true, isVerified: false }` | Boolean value (true or false) |
# | **Date** | `new Date("2024-01-15")` | `{ createdAt: new Date(), birthDate: new Date("2000-05-20") }` | Date and time (stored as milliseconds since Unix epoch) |
# | **Timestamp** | `Timestamp(1, 1)` | `{ lastModified: new Timestamp() }` | Internal MongoDB timestamp (mainly for replication) |
# | **ObjectId** | `ObjectId("507f1f77bcf86cd799439011")` | `{ _id: ObjectId(), userId: ObjectId() }` | 12-byte unique identifier (default for _id field) |
# | **Null** | `null` | `{ name: "Ahmed", middleName: null, nickname: null }` | Represents null or absence of value |
# | **Array** | `[1, 2, 3, "text", true]` | `{ hobbies: ["reading", "coding"], scores: [85, 90, 78] }` | Ordered list of values (can contain mixed types) |
# | **Embedded Document** | `{ city: "Lahore", country: "Pakistan" }` | `{ name: "Sara", address: { street: "Main St", city: "Lahore", zip: "54000" } }` | Nested document/object within a document |
# | **Binary Data** | `BinData(0, "aGVsbG8=")` | `{ filename: "photo.jpg", data: BinData(0, "base64data...") }` | Binary data (images, files, etc.) |
# | **Regular Expression** | `/^test/i` | `{ email: /.*@example\.com$/, pattern: /^[A-Z]/ }` | Pattern matching expression |
# | **JavaScript Code** | `Code("function() { return 1; }")` | `{ validator: Code("function(doc) { return doc.age > 0; }") }` | JavaScript code (for server-side execution) |
# | **Min Key** | `MinKey` | `{ priority: MinKey }` | Special type that compares lower than all other values |
# | **Max Key** | `MaxKey` | `{ priority: MaxKey }` | Special type that compares higher than all other values |
#
# ```bash
# # Example document with various types
# db.examples.insertOne({
#     _id: ObjectId(),
#     name: "Example",
#     count: NumberInt(42),
#     price: NumberDecimal("19.99"),
#     active: true,
#     createdAt: new Date(),
#     tags: ["mongodb", "nosql", "database"],
#     address: {
#         street: "123 Main St",
#         city: "Lahore",
#         country: "Pakistan"
#     }
# })
# ```

# %% [markdown]
# ## d. MongoDB Query Language (MQL) - Read Operations using `mongosh`
# - MongoDB uses MQL (MongoDB Query Language), a JSON-like syntax for querying and manipulating data directly in the shell using methods such as `find()` and `findOne()`.
# - The `find()` method returns a cursor that can be iterated or viewed using `.pretty()` for formatted output
# - The `findOne()` method returns a single document that matches the filter (or null if none found)
#
# ```
# db.collection.find()                     // No arguments → returns all documents
# db.collection.find(filter)               // One argument (query/filter)
# db.collection.find(filter, projection)   // Two arguments (filter + projection)
# ```
# - The **filter** is a JSON-style object that specifies which documents to match, using query operators like `$gt`, `$lt`, `$in`, `$or`, etc. An empty {} means "match all documents"
# - The **projection** specifies which fields to include (1) or exclude (0) from the results. By default, the `_id` field is included unless explicitly excluded using `"_id": 0`

# %% [markdown]
# ### (i) BASIC `find()` and `find_one()` EXAMPLES
# ```bash
# book_store_A> db.books.find()          # Example 1: Find all documents in books collection
# dbook_store_A> db.customers.find()     # Example 2: Find all documents in customer collection
# book_store_A> db.customers.findOne()   # Example 3: Find first document in customers collection
# ```

# %% [markdown]
# ### (ii) PROJECTION (Selecting specific fields)
# ```bash
# book_store_A> db.customers.find({}, {"name": 1, "age": 1})            # Example 4: Include only specific fields (1 = include)
# book_store_A> db.customers.find({}, {"_id": 0, "name": 1, "age": 1})  # Example 5: Include only specific fields (1 = include and 0 = exclude)
# book_store_A> db.books.find({}, {"_id": 0, "price": 0})               # Example 6: Exclude specific fields (0 = exclude)
# ```

# %% [markdown]
# ### (iii) COMPARISON OPERATORS (`$gt`, `$gte`, `$lt`, `$lte`, `$ne`)
# ```bash
# book_store_A> db.books.find({"author": "Dr. Arif"})                                  # Example 7: Find with simple filter (equality)
# book_store_A> db.books.find({"author": {"$ne": "Dr. Arif"}})                         # Example 8: Not equal ($ne)
# book_store_A> db.books.find({"author": "Dr. Arif"}, {"_id":0, "title":1, "price":1}) # Example 9: Find with simple filter (equality)
# book_store_A> db.books.find({"price": {"$gte": 30}})                                 # Example 10: Greater than or equal ($gte)
# book_store_A> db.books.find({"price": {"$gte": 25, "$lte": 35}})                     # Example 11: Range query (combine $gte and $lte)
# book_store_A> db.customers.find({"age": {"$gt": 40}})                                # Example 12: Customers age > 40
# ```

# %% [markdown]
# ### (iv) LOGICAL OPERATORS (`$and`, `$or`, `$not`, `$nor`)
# ```bash
# book_store_A> db.books.find({"$and": [{"price": {"$gt": 25}}, {"author": "Dr. Jamil"}]})   # Example 13: $and operator (multiple conditions)
# book_store_A> db.books.find({"$or": [{"author": "Dr. Arif"}, {"author": "Dr. Rauf"}]})     # Example 14: $or operator (at least one condition true)
# book_store_A> db.books.find({"$or": [{"price": {"$lt": 30}}, {"price": {"$gt": 35}}]})     # Example 15: $or with price conditions
# book_store_A> db.books.find({"price": {"$not": {"$gt": 30}}})                              # Example 16: $not operator
# ```

# %% [markdown]
# ### (v) ARRAY OPERATORS (`$in`, `$nin`)
# ```bash
# book_store_A> db.books.find({"author": {"$in": ["Dr. Arif", "Dr. Rauf"]}})    # Example 17: $in operator (match any value in array)
# book_store_A> db.books.find({"price": {"$in": [25, 40]}})                     # Example 18: $in with numbers
# book_store_A> db.books.find({"author": {"$nin": ["Dr. Arif", "Dr. Jamil"]}})  # Example 19: $nin operator (not in array)
# book_store_A> db.orders.find({"books": "book_101"})                           # Example 20: Find orders containing specific book
# ```

# %% [markdown]
# ### (vi) SORTING
# ```bash
# book_store_A> db.books.find().sort("price", 1)                          # Example 21: Sort ascending (1 = ascending)
# book_store_A> db.books.find().sort("price", -1)                         # Example 22: Sort descending (-1 = descending)
# book_store_A> db.books.find().sort({ price: -1 }).forEach(printjson)    # If sorting  donot work, it may be due to cached output
# book_store_A> db.books.find().sort("title", 1)                          # Example 23: Sort by string field (alphabetical)
# book_store_A> db.customers.find().sort([("age", -1), ("name", 1)])      # Example 24: Multiple field sorting
# book_store_A> db.books.find({"price": {"$gt": 25}}, {"_id": 0, "title": 1, "price": 1}).sort("price", 1) # Example 25: Sort with filter and projection
# ```

# %% [markdown]
# ### (vii) LIMITING RESULTS
# ```bash
# book_store_A> db.books.find().limit(2)                       # Example 26: Limit to first N documents
# book_store_A> db.books.find({"price": {"$gt": 25}}).limit(1) # Example 27: Limit with filter
# ```

# %% [markdown]
# ### (viii) COMBINING EVERYTHING
# ```bash
# book_store_A> db.books.find(query, projection).sort("price", -1).limit(2)  # Example 28: Books > \$25, sorted by price desc, show title only, limit 2
# book_store_A> db.reviews.find({"rating": {"$gte": 4}}).sort("rating", -1)  # Reviews with rating >= 4, sorted by rating desc:")
# ```

# %% [markdown]
# ## e. MongoDB Query Language (MQL) - Update Operations using `mongosh`
# - MongoDB uses MQL (MongoDB Query Language), which is a JSON-based query language accessed through API methods like `updateOne()`, `update_Many()`.
# - The `updateOne()` method updates the first matching document and returns an UpdateResult object, while `updateMany()` method updates all matching documents and returns an UpdateResult object.
# ```
# db.collection.updateOne(filter, update)              # Two arguments (filter + update)
# db.collection.updateMany(filter, update)             # Two arguments (filter + update)
# db.collection.updateOne(filter, update, upsert=True) # Optional: insert if not found
# ```

# %% [markdown]
# ### (i) Update Single Document - `updateOne()`
# **Before:**
# ```bash
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# ```
# **Command:**
# ```bash
# book_store_A> db.books.updateOne({"_id": "book_101"},   {"$set": {"price": 28}})  # update price of book having ID book_101 from 25 to 28
# ```
# **After:**
# ```bash
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 28}
# ```

# %% [markdown]
# ### (ii) Update Multiple Documents - `updateMany()`
# **Before:**
# ```bash
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# ```
# **Command:**
# ```bash
#
# book_store_A> db.books.updateMany({"author": "Dr. Arif"}, {"$inc": {"price": -5}}) # Give 5 rupees discount to all books by Dr. Arif (no $dec operator available)
# ```
# **After:**
# ```bash
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 20}
# ```

# %% [markdown]
# ### (iii) Update Multiple Fields - `$set`
#
# **Before:**
# ```python
# {'_id': 'customer_1', 'name': 'Shaikh Shahid', 'age': 45, 'email': 'shahid@gmail.com'}
# ```
# **Command:**
# ```bash
#
# book_store_A> db.customers.updateOne({"_id": "customer_1"},{"$set": {"age": 46, "email": "shahid_new@gmail.com"}}) # update the age and email of a customer having ID customer_1
# ```
#
# **After:**
# ```python
# {'_id': 'customer_1', 'name': 'Shaikh Shahid', 'age': 46, 'email': 'shahid_new@gmail.com'}
# ```

# %% [markdown]
# ### (iv) Add New Field - `$set`
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 28}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```
# **Command:**
# ```bash
# book_store_A> db.books.updateMany({}, {"$set": {"stock": 100}})  # add a new field stock with a value of 100 in all documents inside the books collection
# ```
# **After:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 28, 'stock': 100}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30, 'stock': 100}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40, 'stock': 100}
# ```

# %% [markdown]
# ### (v) Remove Field - `$unset`
#
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 28, 'stock': 100}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30, 'stock': 100}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40, 'stock': 100}
# ```
# **Command:**
# ```bash
# book_store_A> db.books.updateMany({}, {"$unset": {"stock": ""}})     # Remove stock field from all books
# ```
# **After:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 28}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```

# %% [markdown]
# ## f. MongoDB Query Language (MQL) - Delete Operations using `mongosh`
# - MongoDB uses MQL (MongoDB Query Language), which is a JSON-based query language accessed through API methods like `deleteOne()`, `deleteMany()`.
# - The `deleteOne()` method deletes the first matching document and returns a DeleteResult object, while `deleteMany()` method deletes all matching documents and returns a DeleteResult object.
# ```
# db.collection.delete_one(filter)              # One argument (filter)
# db.collection.delete_many(filter)             # One argument (filter)
# ```

# %% [markdown]
# ### (i) Delete Single Document - `deleteOne()`
# **Before:**
# ```python
# {'_id': 'review_1', 'book': 'book_101', 'rating': 5, 'comment': 'Excellent for beginners!'}
# {'_id': 'review_2', 'book': 'book_103', 'rating': 4, 'comment': 'Good coverage of concepts.'}
# ```
# **Command:**
# ```bash
# book_store_A> db.reviews.deleteOne({"_id": "review_1"})
# ```
# **After:**
# ```python
# {'_id': 'review_2', 'book': 'book_103', 'rating': 4, 'comment': 'Good coverage of concepts.'}
# ```

# %% [markdown]
# ### (ii) Delete Multiple Documents - `deleteMany()`
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```
# **Command:**
# ```bash
# book_store_A> db.books.deleteMany({"price": {"$lte": 30}})
# ```
#
# **After:**
# ```python
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```

# %% [markdown]
# ## g. Indexing
# - **What is Indexing?** Indexing in MongoDB improves the efficiency of search operations by allowing the database to locate documents without scanning every one. It's like an index in a textbook.
# - **Benefits of Indexing:**
#     - Faster queries
#     - Improved performance for large datasets
#     - Reduced resource usage
#     - Indexing also helps in sorting
# - **Trade-Offs of Indexing:**
#     -  Indexes require additional memory and disk to store.
#     -  Insert, update, and delete operations can become slower, as indexes need to be updated each time.
# - **When not to use indexing in mongodb:**
#     - When the collection is small
#     - When the collection is frequently updated
#     - When the queries are complex(multiple fields)
#     - When the collection is large(make less indices)
#
# - **Types of Indexes in MongoDB:**
#
# | Index Type | Description | Advantage | When to Use | Example |
# |------------|-------------|-----------|-------------|---------|
# | **Single Field Index** | Creates an index on a single field of a document | Fast queries on one specific field | When filtering or sorting by a single field frequently | `db.users.createIndex({ email: 1 })` - Quick lookups by email |
# | **Compound Index** | Creates an index on multiple fields in a specific order | Efficient queries that filter or sort by multiple fields together | When queries use multiple fields in WHERE clauses or sorting | `db.users.createIndex({ lastName: 1, firstName: 1 })` - Search by last name and first name |
# | **Text Index** | Creates a full-text search index on string content | Enables searching for words/phrases within text fields | When implementing search functionality across text content | `db.articles.createIndex({ title: "text", content: "text" })` - Search articles by keywords |
#
# <table style="width:100%; border-collapse: collapse;">
#   <tr>
#     <td style="padding: 18px; vertical-align: top; font-size: 15px; line-height: 1.6;">
#       🔸 When there is no index, MongoDB performs a <strong>COLLSCAN (Collection Scan)</strong> — it checks every document one by one, which is slow for large collections.
#       <h3 style="margin-top: 20px;">⚙️ How Indexing Works Internally</h3>
#       <ul>
#         <li>MongoDB stores indexes using the <strong>B-tree (Balanced Tree)</strong> data structure.</li>
#         <li>B-trees store <strong>index keys</strong> along with <strong>pointers to the actual documents</strong> in the collection.</li>
#         <li>The structure allows fast traversal, insertions, deletions, and range-based queries.</li>
#       </ul>
#     </td>
#     <td style="text-align: center; padding: 20px;">
#       <img src="../images/picsiee.png" alt="MongoDB Indexing" style="width: 500px; border: 1px solid #ccc;"/>
#     </td>
#   </tr>
# </table>

# %%
# Thanks to my students, who are also my teachers
from IPython.display import Video

Video("../images/indexing.mp4", width=800, height=450)
# Out:
# <video src="../images/indexing.mp4" controls  width="800"  height="450">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### (i) Single Field Index
# - A single-field index is created on one field of a collection and is useful when your queries frequently filter or sort by that field.
# - Suppose we often search for books by their author. Without an index, MongoDB would scan every document (collection scan), while with the index on author, it can jump directly to matching entries
# ```bash
# book_store_A> db.books.createIndex({"author": 1})         # creates an ascending index on the author field. (1 = ascending order)
# book_store_A> db.books.find({"author": "Dr. Arif"})        # Such queries will now be faster
# book_store_A> db.books.find({"author": "Dr. Arif"}).explain("executionStats")
# ```

# %% [markdown]
# ### (ii) Compound Index
# - A compound index includes multiple fields in a single index, and is useful when queries involve filtering or sorting on more than one field.
# - Suppose we often search for books by both author and price. Without an index, MongoDB would scan every document (collection scan), while with the index on author and price, it can jump directly to matching entries
# - Order matters in compound indexes — {author: 1, price: -1} is different from {price: -1, author: 1}. Design them based on the most common query patterns.
# ```bash
# book_store_A> db.books.createIndex({"author": 1, "price": -1})          # creates an index sorted by author (ascending) and then by price (descending).
# book_store_A> db.books.find({"author": "Dr. Arif"}).sort("price", -1)    # Such queries will now be faster
# ```

# %% [markdown]
# ### (iii) Text Index
# - A text index allows full-text search on string fields (like searching words in titles or comments), and is useful when you want to support keyword searches.
# - MongoDB’s text index tokenizes and normalizes words to enable keyword searching.
# - It supports operators like `$search`, `$language`, and `$caseSensitive`.
# ```bash
# book_store_A> db.books.createIndex({"title": "text"})                       # enable keyword search in book titles in books collection
# book_store_A> db.reviews.createIndex({"comment": "text", "book": "text"})   # enable keyword search on comments and book titles in reviews collections
#
# # Now you can perform full-text searches like:
# book_store_A> db.books.find({"$text": {"$search": "MongoDB"}})
# book_store_A> db.reviews.find({"$text": {"$search": "Excellent"}})
#
# # List all indexes on books collection
# book_store_A> db.books.getIndexes()
#
# # Drop all indexes from books collection
# book_store_A> db.books.dropIndexes()
#
# # List all indexes on reviews collection
# book_store_A> db.reviews.getIndexes()
#
# # Drop a specific index by name from reviews collection
# book_store_A> db.reviews.dropIndex("comment_text_book_text")

# %% [markdown]
# ### (iv) List and Drop Indexes
# ```bash
# # List all indexes on books collection
# book_store_A> db.books.getIndexes()
#
# # Drop all indexes from books collection
# book_store_A> db.books.dropIndexes()
#
# # List all indexes on reviews collection
# book_store_A> db.reviews.getIndexes()
#
# # Drop a specific index by name from reviews collection
# book_store_A> db.reviews.dropIndex("comment_text_book_text")
#
# ```

# %% [markdown]
# # <span style='background :lightgreen' >4. Hands-On Practice of Accessing MongoDB via Python's `pymongo` Module</span>
# - Before working with MongoDB in Python, you need to install the official MongoDB driver called `pymongo`.
# - Install pymongo in the current environment: `!pip install pymongo`
# - Once installed, you can use `pymongo` to connect to your local MongoDB server from Python code.
#
# ```
# 📦 book_store
# │
# ├── 📁 books
# │  ├── 📄 book_101 – { title: "MongoDB Basics", author: "Dr. Arif", price: 25 }
# │  ├── 📄 book_102 – { title: "Python for All", author: "Dr. Jamil", price: 30 }
# │  └── 📄 book_103 – { title: "AI in Action", author: "Dr. Rauf", price: 40 }
# │
# ├── 📁 customers
# │  ├── 📄 customer_1 – { name: "Shaikh Shahid", age: 45, email: "shahid@gmail.com" }
# │  ├── 📄 customer_2 – { name: "Waqas Aslam", age: 55, email: "waqas@yahoo.com" }
# │  └── 📄 customer_3 – { name: "Umer Khan", age: 30, email: "umer@outlook.com" }
# │
# ├── 📁 orders
# │  ├── 📄 order_1 – { customer: "Tipu Sultan", books: ["book_101", "book_103"], total: 65 }
# │  └── 📄 order_2 – { customer: "Tipu Sultan", books: ["book_102"], total: 30 }
# │
# └── 📁 reviews
#    ├── 📄 review_1 – { book: "book_101", rating: 5, comment: "Excellent for beginners!" }
#    └── 📄 review_2 – { book: "book_103", rating: 4, comment: "Good coverage of concepts." }
# ```
#
# | Method | Example | Description & Return Type |
# |--------|---------|---------------------------|
# | `MongoClient()` | `client = MongoClient("mongodb://localhost:27017/")` | Creates a connection to MongoDB server<br>Returns: `MongoClient` object |
# | `drop_database()` | `client.drop_database("book_store")` | Deletes an entire database and all its collections<br>Returns: `None` |
# | `client["db"]` | `db = client["book_store"]` | Accesses a database (creates it lazily on first write)<br>Returns: `Database` object |
# | `db["collection"]` | `collection = db["books"]` | Accesses a collection (creates it lazily on first write)<br>Returns: `Collection` object |
# | `create_collection()` | `db.create_collection("books")` | Explicitly creates a collection (optional in MongoDB)<br>Returns: `Collection` object |
# | `insert_one()` | `result = db.books.insert_one({"title": "MongoDB Basics", "author": "Dr. Arif", "price": 25})` | Inserts a single document into collection<br>Returns: `InsertOneResult` with `.inserted_id` attribute |
# | `insert_many()` | `result = db.books.insert_many([{"title": "Python for All", "price": 30}, {"title": "AI in Action", "price": 40}])` | Inserts multiple documents into collection<br>Returns: `InsertManyResult` with `.inserted_ids` (list) attribute |
# | `find()` | `cursor = db.books.find({"price": {"$gt": 25}})` | Queries collection and returns all matching documents<br>Returns: `Cursor` object (iterable of dicts) |
# | `find_one()` | `doc = db.books.find_one({"_id": "book_101"})` | Queries collection and returns first matching document<br>Returns: `dict` or `None` if not found |
# | `find()` with projection | `cursor = db.books.find({}, {"title": 1, "price": 1, "_id": 0})` | Returns only specified fields (1=include, 0=exclude)<br>Returns: `Cursor` object with projected fields |
# | `find()` with sort | `cursor = db.books.find().sort("price", -1)` | Sorts results (1=ascending, -1=descending)<br>Returns: `Cursor` object with sorted documents |
# | `find()` with limit | `cursor = db.books.find().limit(2)` | Limits number of returned documents<br>Returns: `Cursor` object with limited results |
# | `find()` combined | `cursor = db.books.find({"price": {"$gte": 30}}, {"title": 1}).sort("price", 1).limit(2)` | Combines filter, projection, sort, and limit<br>Returns: `Cursor` object |
# | `update_one()` | `result = db.books.update_one({"_id": "book_101"}, {"$set": {"price": 28}})` | Updates first document matching the filter<br>Returns: `UpdateResult` with `.matched_count`, `.modified_count` |
# | `update_many()` | `result = db.books.update_many({"author": "Dr. Arif"}, {"$inc": {"price": 5}})` | Updates all documents matching the filter<br>Returns: `UpdateResult` with `.matched_count`, `.modified_count` |
# | `replace_one()` | `result = db.books.replace_one({"_id": "book_101"}, {"title": "MongoDB Advanced", "author": "Dr. Arif", "price": 35})` | Replaces entire document (except _id) matching filter<br>Returns: `UpdateResult` with `.matched_count`, `.modified_count` |
# | `delete_one()` | `result = db.reviews.delete_one({"_id": "review_1"})` | Deletes first document matching the filter<br>Returns: `DeleteResult` with `.deleted_count` (0 or 1) |
# | `delete_many()` | `result = db.books.delete_many({"price": {"$lt": 30}})` | Deletes all documents matching the filter<br>Returns: `DeleteResult` with `.deleted_count` |
# | `count_documents()` | `count = db.books.count_documents({"price": {"$gte": 30}})` | Counts documents matching the filter<br>Returns: `int` |
# | `distinct()` | `authors = db.books.distinct("author")` | Returns array of distinct values for a field<br>Returns: `list` |
# | `find_one_and_update()` | `doc = db.customers.find_one_and_update({"_id": "customer_1"}, {"$set": {"age": 46}})` | Finds, updates, and returns the document (before update by default)<br>Returns: `dict` or `None` |
# | `find_one_and_replace()` | `doc = db.customers.find_one_and_replace({"_id": "customer_1"}, {"name": "New Name", "email": "new@email.com"})` | Finds, replaces, and returns the document (before replace by default)<br>Returns: `dict` or `None` |
# | `find_one_and_delete()` | `doc = db.reviews.find_one_and_delete({"_id": "review_1"})` | Finds, deletes, and returns the deleted document<br>Returns: `dict` or `None` |
# | `list_collection_names()` | `collections = db.list_collection_names()` | Returns list of all collection names in database<br>Returns: `list` of strings |
# | `drop()` | `db.books.drop()` | Drops (deletes) an entire collection<br>Returns: `None` |
# | `close()` | `client.close()` | Closes the MongoDB connection and releases resources<br>Returns: `None` |

# %% [markdown]
# ## a. MongoDB Query Language (MQL)  - Create Operations using `pymongo`

# %%
from pymongo import MongoClient

# Connect to MongoDB (adjust connection string as needed). Returns a client instance for connecting to MongoDB server
client = MongoClient("mongodb://localhost:27017/")

# Silently drops the database if it exists, no return value
client.drop_database("book_store_B")

# Returns the reference to a specific database (created lazily on first write operation)
db = client["book_store_B"]

# ===== CREATE THREE COLLECTIONS EXPLICITLY =====
# In MongoDB, explicit collection creation is optional because a collection is automatically created when you insert a document into a non-existing collection.
db.create_collection("books")
db.create_collection("reviews")
db.create_collection("customers")
db.create_collection("orders")


# ===== DISPLAY DATABASE SUMMARY =====
print(f"Database: book_store")
print(f"   books collection: {db.books.count_documents({})} documents")
print(f"   reviews collection: {db.reviews.count_documents({})} documents")
print(f"   customers collection: {db.customers.count_documents({})} documents")
print(f"   orders collection: {db.orders.count_documents({})} documents")
# Out:
# Database: book_store
#    books collection: 0 documents
#    reviews collection: 0 documents
#    customers collection: 0 documents
#    orders collection: 0 documents

# %% [markdown]
# ## b. MongoDB Query Language (MQL)  - Insert Operations using `pymongo`
# - MongoDB uses MQL (MongoDB Query Language) to perform insert operations through API methods like `insert_one()` and `insert_many()`.
# - These methods allow you to add new documents into a collection in a flexible, schema-less JSON format (BSON internally).
# ```
# db.collection.insert_one(document)          # Inserts a single document
# db.collection.insert_many([document1, document2, ...])   # Inserts multiple documents
#
# ```
# - The document is a Python dictionary (in PyMongo) or JSON object (in shell) representing the data to be inserted.
# - Each inserted document automatically gets a unique _id field (ObjectId) if not provided.

# %%
# ===== COLLECTION 1: books =====
print("Inserting documents into 'books' collection...")

# Use auto-generated IDs unless you have a specific reason for custom ones!
result = db.books.insert_one({"_id": "book_101", "title": "MongoDB Basics", "author": "Dr. Arif",  "price": 25})
print(f"Document inserted with ID: {result.inserted_id}")

books = db.books.insert_many([
            {"_id": "book_102", "title": "Python for All", "author": "Dr. Jamil", "price": 30},
            {"_id": "book_103", "title": "AI in Action", "author": "Dr. Rauf", "price": 40}
    ])
total_books = 1 + len(books.inserted_ids)
print(f"Inserted {total_books} books\n")
# Out:
# Inserting documents into 'books' collection...
# Document inserted with ID: book_101
# Inserted 3 books

# %%
# ===== COLLECTION 2: reviews =====
print("📁 Inserting documents into 'reviews' collection...")
reviews = db.reviews.insert_many([
            {"_id": "review_1", "book": "book_101", "rating": 5, "comment": "Excellent for beginners!"},
            {"_id": "review_2", "book": "book_103", "rating": 4, "comment": "Good coverage of concepts."}
    ])
print(f"   ✓ Inserted {len(reviews.inserted_ids)} reviews\n")
# Out:
# 📁 Inserting documents into 'reviews' collection...
#    ✓ Inserted 2 reviews

# %%
# ===== COLLECTION 3: customers =====
print("📁 Inserting documents into 'customers' collection...")
customers = db.customers.insert_many([
            {"_id": "customer_1", "name": "Shaikh Shahid", "age": 45, "email": "shahid@gmail.com"},
            {"_id": "customer_2", "name": "Waqas Aslam", "age": 55, "email": "waqas@yahoo.com"},
            {"_id": "customer_3", "name": "Umer Khan", "age": 30, "email": "umer@outlook.com"}
    ])
print(f"   ✓ Inserted {len(customers.inserted_ids)} customers\n")
# Out:
# 📁 Inserting documents into 'customers' collection...
#    ✓ Inserted 3 customers

# %%
# ===== COLLECTION 4: orders =====
print("📁 Inserting documents into 'orders' collection...")
orders = db.orders.insert_many([
            {"_id": "order_1", "customer": "Tipu Sultan", "books": ["book_101", "book_103"], "total": 65},
            {"_id": "order_2", "customer": "Salah ud Din", "books": ["book_102"], "total": 30}
    ])
print(f"   ✓ Inserted {len(orders.inserted_ids)} orders\n")
# Out:
# 📁 Inserting documents into 'orders' collection...
#    ✓ Inserted 2 orders

# %%
# ===== DISPLAY DATABASE SUMMARY =====
print(f"\n📦 Database: book_store")
print(f"   📁 books collection: {db.books.count_documents({})} documents")
print(f"   📁 reviews collection: {db.reviews.count_documents({})} documents")
print(f"   📁 customers collection: {db.customers.count_documents({})} documents")
print(f"   📁 orders collection: {db.orders.count_documents({})} documents")
# Out:
# 📦 Database: book_store
#    📁 books collection: 3 documents
#    📁 reviews collection: 2 documents
#    📁 customers collection: 3 documents
#    📁 orders collection: 2 documents

# %% [markdown]
# ## c. MongoDB Query Language (MQL) - Read Operations  using `pymongo`
# - MongoDB uses MQL (MongoDB Query Language), which is a JSON-based query language accessed through API methods like find() and insert_one().
# - The `find()` method returns an iterable cursor object containing all matching documents, while `find_one()` method returns only the first matching document as a dictionary.
# ```
# db.collection.find()                    # No arguments
# db.collection.find(filter)              # One argument (query/filter)
# db.collection.find(filter, projection)  # Two arguments (filter + projection)
# ```
# - The **filter** is a dictionary that specifies which documents to match, using query operators like $gt, $lt, $in, $or, etc. An empty {} means "match all documents"
# - The  **projection** is a dictionary that specifies which fields to include or exclude
# 1 = include field, 0 = exclude field
# By default, _id is always included unless explicitly excluded with "_id": 0

# %% [markdown]
# ### (i) BASIC `find()` and `find_one()` EXAMPLES

# %%
# Example 1: Find one document
print("\n1. Find ONE book:")
book = db.books.find_one()
print(f"   {book}")
# Out:
# 1. Find ONE book:
#    {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}

# %%
# Example 2: Find all documents in books collection
print("\n2. Find ALL books (no filter):")
for book in db.books.find():
    print(f"   {book}")
# Out:
# 2. Find ALL books (no filter):
#    {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
#    {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
#    {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}

# %%
# Example 3: Find all documents in customers collection
print("\n3. Find ALL customers (no filter):")
for customer in db.customers.find():
    print(f"   {customer}")
# Out:
# 3. Find ALL customers (no filter):
#    {'_id': 'customer_1', 'name': 'Shaikh Shahid', 'age': 45, 'email': 'shahid@gmail.com'}
#    {'_id': 'customer_2', 'name': 'Waqas Aslam', 'age': 55, 'email': 'waqas@yahoo.com'}
#    {'_id': 'customer_3', 'name': 'Umer Khan', 'age': 30, 'email': 'umer@outlook.com'}

# %% [markdown]
# ### (ii) PROJECTION (Selecting specific fields)

# %%
# Example 4: Include only specific fields (1 = include)
print("\n4. Get only name and age")
for customer in db.customers.find({}, {"name": 1, "age": 1}):
    print(f"   {customer}")
# Out:
# 4. Get only name and age
#    {'_id': 'customer_1', 'name': 'Shaikh Shahid', 'age': 45}
#    {'_id': 'customer_2', 'name': 'Waqas Aslam', 'age': 55}
#    {'_id': 'customer_3', 'name': 'Umer Khan', 'age': 30}

# %%
# Example 5: Include only specific fields (1 = include and 0 = exclude)
print("\n5. Get only name and age (exclude _id):")
for customer in db.customers.find({}, {"_id": 0, "name": 1, "age": 1}):
    print(f"   {customer}")
# Out:
# 5. Get only name and age (exclude _id):
#    {'name': 'Shaikh Shahid', 'age': 45}
#    {'name': 'Waqas Aslam', 'age': 55}
#    {'name': 'Umer Khan', 'age': 30}

# %%
# Example 6: Exclude specific fields (0 = exclude)
print("\n6. Get all fields EXCEPT id and price:")
for book in db.books.find({}, {"_id": 0, "price": 0}):
    print(f"   {book}")
# Out:
# 6. Get all fields EXCEPT id and price:
#    {'title': 'MongoDB Basics', 'author': 'Dr. Arif'}
#    {'title': 'Python for All', 'author': 'Dr. Jamil'}
#    {'title': 'AI in Action', 'author': 'Dr. Rauf'}

# %% [markdown]
# ### (iii) COMPARISON OPERATORS (`$gt`, `$gte`, `$lt`, `$lte`, `$ne`)

# %%
# Example 7: Find with simple filter (equality)
print("\n7. Find all books by 'Dr. Arif':")
for book in db.books.find({"author": "Dr. Arif"}):
    print(f"   {book}")
# Out:
# 7. Find all books by 'Dr. Arif':
#    {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}

# %%
# Example 8: Not equal ($ne)
print("\n8. Books NOT written by 'Dr. Arif':")
for book in db.books.find({"author": {"$ne": "Dr. Arif"}}):
    print(f"   {book}")
# Out:
# 8. Books NOT written by 'Dr. Arif':
#    {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
#    {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}

# %%
# Example 9: Find with simple filter (equality)
print("\n9. Find all books by 'Dr. Arif' and display only title and price:")
for book in db.books.find({"author": "Dr. Arif"}, {"_id":0, "title":1, "price":1}):
    print(f"   {book}")
# Out:
# 9. Find all books by 'Dr. Arif' and display only title and price:
#    {'title': 'MongoDB Basics', 'price': 25}

# %%
# Example 10: Greater than or equal ($gte)
print("\n10. Books with price >= 30:")
for book in db.books.find({"price": {"$gte": 30}}):
    print(f"   {book}")
# Out:
# 10. Books with price >= 30:
#    {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
#    {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}

# %%
# Example 11: Range query (combine $gte and $lte)
print("\n11. Books priced between 25 and 35 (inclusive):")
for book in db.books.find({"price": {"$gte": 25, "$lte": 35}}):
    print(f"   {book}")
# Out:
# 11. Books priced between 25 and 35 (inclusive):
#    {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
#    {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}

# %%
# Example 12: Customers age > 40
print("\n15. Customers older than 40:")
for customer in db.customers.find({"age": {"$gt": 40}}):
    print(f"   {customer['name']}: {customer['age']} years old")
# Out:
# 15. Customers older than 40:
#    Shaikh Shahid: 45 years old
#    Waqas Aslam: 55 years old

# %% [markdown]
# ### (iv) LOGICAL OPERATORS (`$and`, `$or`, `$not`, `$nor`)

# %%
# Example 13: $and operator (multiple conditions)
print("\n13. Books with price > 25 AND author is 'Dr. Jamil':")
for book in db.books.find({"$and": [{"price": {"$gt": 25}}, {"author": "Dr. Jamil"}]}):
    print(f"   {book}")
# Out:
# 13. Books with price > 25 AND author is 'Dr. Jamil':
#    {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}

# %%
# Example 14: $or operator (at least one condition true)
print("\n14. Books by 'Dr. Arif' OR 'Dr. Rauf':")
for book in db.books.find({"$or": [{"author": "Dr. Arif"}, {"author": "Dr. Rauf"}]}):
    print(f"   {book['title']} by {book['author']}")
# Out:
# 14. Books by 'Dr. Arif' OR 'Dr. Rauf':
#    MongoDB Basics by Dr. Arif
#    AI in Action by Dr. Rauf

# %%
# Example 15: $or with price conditions
print("\n15. Books priced < 30 OR > 35:")
for book in db.books.find({"$or": [{"price": {"$lt": 30}}, {"price": {"$gt": 35}}]}):
    print(f"   {book['title']}: ${book['price']}")
# Out:
# 15. Books priced < 30 OR > 35:
#    MongoDB Basics: $25
#    AI in Action: $40

# %%
# Example 16: $not operator
print("\n16. Books with price NOT greater than 30:")
for book in db.books.find({"price": {"$not": {"$gt": 30}}}):
    print(f"   {book['title']}: ${book['price']}")
# Out:
# 16. Books with price NOT greater than 30:
#    MongoDB Basics: $25
#    Python for All: $30

# %% [markdown]
# ### (v) ARRAY OPERATORS (`$in`, `$nin`)

# %%
# Example 17: $in operator (match any value in array)
print("\n17. Books by authors in list ['Dr. Arif', 'Dr. Rauf']:")
for book in db.books.find({"author": {"$in": ["Dr. Arif", "Dr. Rauf"]}}):
    print(f"   {book}")
# Out:
# 17. Books by authors in list ['Dr. Arif', 'Dr. Rauf']:
#    {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
#    {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}

# %%
# Example 18: $in with numbers
print("\n18. Books priced 25 or 40:")
for book in db.books.find({"price": {"$in": [25, 40]}}):
    print(f"   {book}")
# Out:
# 18. Books priced 25 or 40:
#    {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
#    {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}

# %%
# Example 19: $nin operator (not in array)
print("\n19. Books NOT by 'Dr. Arif' or 'Dr. Jamil':")
for book in db.books.find({"author": {"$nin": ["Dr. Arif", "Dr. Jamil"]}}):
    print(f"   {book['title']} by {book['author']}")
# Out:
# 19. Books NOT by 'Dr. Arif' or 'Dr. Jamil':
#    AI in Action by Dr. Rauf

# %%
# Example 20: Find orders containing specific book
print("\n20. Orders containing 'book_101':")
for order in db.orders.find({"books": "book_101"}):
    print(f"   {order}")
# Out:
# 20. Orders containing 'book_101':
#    {'_id': 'order_1', 'customer': 'Tipu Sultan', 'books': ['book_101', 'book_103'], 'total': 65}

# %% [markdown]
# ### (vi) SORTING

# %%
# Example 21: Sort ascending (1 = ascending)
print("\n21. Books sorted by price (ascending):")
for book in db.books.find().sort("price", 1):
    print(f"   ${book['price']}: {book['title']}")
# Out:
# 21. Books sorted by price (ascending):
#    $25: MongoDB Basics
#    $30: Python for All
#    $40: AI in Action

# %%
# Example 22: Sort descending (-1 = descending)
print("\n22. Books sorted by price (descending):")
for book in db.books.find().sort("price", -1):
    print(f"   ${book['price']}: {book['title']}")
# Out:
# 22. Books sorted by price (descending):
#    $40: AI in Action
#    $30: Python for All
#    $25: MongoDB Basics

# %%
# Example 23: Sort by string field (alphabetical)
print("\n23. Books sorted by title (A-Z):")
for book in db.books.find().sort("title", 1):
    print(f"   {book['title']}")
# Out:
# 23. Books sorted by title (A-Z):
#    AI in Action
#    MongoDB Basics
#    Python for All

# %%
# Example 24: Multiple field sorting
print("\n24. Customers sorted by age (desc), then name (asc):")
for customer in db.customers.find().sort([("age", -1), ("name", 1)]):
    print(f"   {customer['name']}: {customer['age']} years")
# Out:
# 24. Customers sorted by age (desc), then name (asc):
#    Waqas Aslam: 55 years
#    Shaikh Shahid: 45 years
#    Umer Khan: 30 years

# %%
# Example 25: Sort with filter and projection
print("\n25. Books > $25, sorted by price, show title and price only:")
for book in db.books.find({"price": {"$gt": 25}}, {"_id": 0, "title": 1, "price": 1}).sort("price", 1):
    print(f"   {book}")
# Out:
# 25. Books > $25, sorted by price, show title and price only:
#    {'title': 'Python for All', 'price': 30}
#    {'title': 'AI in Action', 'price': 40}

# %% [markdown]
# ### (vii) LIMITING RESULTS

# %%
# Example 26: Limit to first N documents
print("\n26. First 2 books:")
for book in db.books.find().limit(2):
    print(f"   {book}")
# Out:
# 26. First 2 books:
#    {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
#    {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}

# %%
# Example 27: Limit with filter
print("\n27. First 1 book priced > 25:")
for book in db.books.find({"price": {"$gt": 25}}).limit(1):
    print(f"   {book['title']}: ${book['price']}")
# Out:
# 27. First 1 book priced > 25:
#    Python for All: $30

# %% [markdown]
# ### (viii) COMBINING EVERYTHING

# %%
# Example 28: Complex query 1
print("\n28. Books > $25, sorted by price desc, show title only, limit 2:")
query = {"price": {"$gt": 25}}
projection = {"_id": 0, "title": 1, "price": 1}
for book in db.books.find(query, projection).sort("price", -1).limit(2):
    print(f"   {book}")
# Out:
# 28. Books > $25, sorted by price desc, show title only, limit 2:
#    {'title': 'AI in Action', 'price': 40}
#    {'title': 'Python for All', 'price': 30}

# %%
# Example 29: Complex query 2
print("\n29. Customers age 30-50, sorted by age, show name and email:")
query = {"age": {"$gte": 30, "$lte": 50}}
projection = {"_id": 0, "name": 1, "email": 1, "age": 1}
for customer in db.customers.find(query, projection).sort("age", 1):
    print(f"   {customer}")
# Out:
# 29. Customers age 30-50, sorted by age, show name and email:
#    {'name': 'Umer Khan', 'age': 30, 'email': 'umer@outlook.com'}
#    {'name': 'Shaikh Shahid', 'age': 45, 'email': 'shahid@gmail.com'}

# %%
# Example 30: Complex query 3
print("\n30. Reviews with rating >= 4, sorted by rating desc:")
for review in db.reviews.find({"rating": {"$gte": 4}}).sort("rating", -1):
    print(f"   Rating: {review['rating']} - {review['comment']}")
# Out:
# 30. Reviews with rating >= 4, sorted by rating desc:
#    Rating: 5 - Excellent for beginners!
#    Rating: 4 - Good coverage of concepts.

# %%
# Example 31: Find with exists operator
print("\n31. Find all documents in books collection:")
for book in db.books.find({"title": {"$exists": True}}):
    print(f"   {book['title']}")
# Out:
# 31. Find all documents in books collection:
#    MongoDB Basics
#    Python for All
#    AI in Action

# %% [markdown]
# ## d. MongoDB Query Language (MQL) - Update Operations  using `pymongo`
# - MongoDB uses MQL (MongoDB Query Language), which is a JSON-based query language accessed through API methods like `update_one()`, `update_many()`, and `replace_one()`.
# - The `update_one()` method updates the first matching document and returns an UpdateResult object, while `update_many()` method updates all matching documents and returns an UpdateResult object.
# ```
# db.collection.update_one(filter, update)              # Two arguments (filter + update)
# db.collection.update_many(filter, update)             # Two arguments (filter + update)
# db.collection.update_one(filter, update, upsert=True) # Optional: insert if not found
# ```

# %% [markdown]
# ### (i) Update Single Document - `update_one()`
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# ```
#
# **After:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 28}
# ```

# %%
# Update price of book_101 from 25 to 28
result = db.books.update_one(
    {"_id": "book_101"},              # Filter: which document to update
    {"$set": {"price": 28}}           # Update: set new price
)

print(f"Matched: {result.matched_count}")      # 1
print(f"Modified: {result.modified_count}")    # 1
# Out:
# Matched: 1
# Modified: 1

# %% [markdown]
# ### (ii) Update Multiple Documents - `update_many()`
#
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# ```
#
# **After:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 20}
# ```

# %%
# Give 5 rupees discount to all books by Dr. Arif
result = db.books.update_many(
    {"author": "Dr. Arif"},           # Filter: all books by Dr. Arif
    {"$inc": {"price": -5}}            # Update: Decrement price by 5
)

print(f"Matched: {result.matched_count}")      # Number of books found
print(f"Modified: {result.modified_count}")    # Number of books updated
# Out:
# Matched: 1
# Modified: 1

# %% [markdown]
# ### (iii) Update Multiple Fields - `$set`
#
# **Before:**
# ```python
# {'_id': 'customer_1', 'name': 'Shaikh Shahid', 'age': 45, 'email': 'shahid@gmail.com'}
# ```
#
# **After:**
# ```python
# {'_id': 'customer_1', 'name': 'Shaikh Shahid', 'age': 46, 'email': 'shahid_new@gmail.com'}
# ```

# %%
# Update multiple fields for customer_1
result = db.customers.update_one(
    {"_id": "customer_1"},                    # Filter
    {"$set": {                                # Update multiple fields
        "age": 46,
        "email": "shahid_new@gmail.com"
    }}
)

print(f"Matched: {result.matched_count}")
print(f"Modified: {result.modified_count}")
# Out:
# Matched: 1
# Modified: 1

# %% [markdown]
# ### (iv) Add New Field - `$set`
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```
#
# **After:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25, 'stock': 100}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30, 'stock': 100}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40, 'stock': 100}
# ```

# %%
# Add stock field to all books
result = db.books.update_many(
    {},                               # Empty filter = all documents
    {"$set": {"stock": 100}}          # Add new field
)

print(f"Matched: {result.matched_count}")
print(f"Modified: {result.modified_count}")
# Out:
# Matched: 3
# Modified: 3

# %% [markdown]
# ### (v) Remove Field - `$unset`
#
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25, 'stock': 100}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30, 'stock': 100}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40, 'stock': 100}
# ```
# **After:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```

# %%
# Remove stock field from all books
result = db.books.update_many(
    {},                               # All documents
    {"$unset": {"stock": ""}}         # Remove field (value doesn't matter)
)

print(f"Matched: {result.matched_count}")
print(f"Modified: {result.modified_count}")
# Out:
# Matched: 3
# Modified: 3

# %% [markdown]
# ## e. MongoDB Query Language (MQL) - Delete Operations  using `pymongo`
# - MongoDB uses MQL (MongoDB Query Language), which is a JSON-based query language accessed through API methods like `delete_one()`, `delete_many()`, and `find_one_and_delete()`.
# - The `delete_one()` method deletes the first matching document and returns a DeleteResult object, while `delete_many()` method deletes all matching documents and returns a DeleteResult object.
# ```
# db.collection.delete_one(filter)              # One argument (filter)
# db.collection.delete_many(filter)             # One argument (filter)
# db.collection.find_one_and_delete(filter)     # Deletes and returns the document
# ```

# %% [markdown]
# ### (i) Delete Single Document - `delete_one()`
# **Before:**
# ```python
# {'_id': 'review_1', 'book': 'book_101', 'rating': 5, 'comment': 'Excellent for beginners!'}
# {'_id': 'review_2', 'book': 'book_103', 'rating': 4, 'comment': 'Good coverage of concepts.'}
# ```
#
# **After:**
# ```python
# {'_id': 'review_2', 'book': 'book_103', 'rating': 4, 'comment': 'Good coverage of concepts.'}
# ```

# %%
# Delete review_1
result = db.reviews.delete_one({"_id": "review_1"})

print(f"Deleted count: {result.deleted_count}")    # 1
print(f"Acknowledged: {result.acknowledged}")      # True
# Out:
# Deleted count: 1
# Acknowledged: True

# %% [markdown]
# ### (ii) Delete Multiple Documents - `delete_many()`
# **Before:**
# ```python
# {'_id': 'book_101', 'title': 'MongoDB Basics', 'author': 'Dr. Arif', 'price': 25}
# {'_id': 'book_102', 'title': 'Python for All', 'author': 'Dr. Jamil', 'price': 30}
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```
#
# **After:**
# ```python
# {'_id': 'book_103', 'title': 'AI in Action', 'author': 'Dr. Rauf', 'price': 40}
# ```

# %%
# Delete all books with price < 30
result = db.books.delete_many({"price": {"$lte": 30}})

print(f"Deleted count: {result.deleted_count}")    # Number of books deleted
print(f"Acknowledged: {result.acknowledged}")      # True
# Out:
# Deleted count: 2
# Acknowledged: True

# %% [markdown]
# ## f. INDEXING
# - **What is Indexing?** Indexing in MongoDB improves the efficiency of search operations by allowing the database to locate documents without scanning every one. It's like an index in a textbook.
# - **Benefits of Indexing:**
#     - Faster queries
#     - Improved performance for large datasets
#     - Reduced resource usage
#     - Indexing also helps in sorting
# - **Trade-Offs of Indexing:**
#     -  Indexes require additional memory and disk to store.
#     -  Insert, update, and delete operations can become slower, as indexes need to be updated each time.
# - **When not to use indexing in mongodb:**
#     - When the collection is small
#     - When the collection is frequently updated
#     - When the queries are complex(multiple fields)
#     - When the collection is large(make less indices)
#
# - **Types of Indexes in MongoDB:**
#
# | Index Type | Description | Advantage | When to Use | Example |
# |------------|-------------|-----------|-------------|---------|
# | **Single Field Index** | Creates an index on a single field of a document | Fast queries on one specific field | When filtering or sorting by a single field frequently | `db.users.createIndex({ email: 1 })` - Quick lookups by email |
# | **Compound Index** | Creates an index on multiple fields in a specific order | Efficient queries that filter or sort by multiple fields together | When queries use multiple fields in WHERE clauses or sorting | `db.users.createIndex({ lastName: 1, firstName: 1 })` - Search by last name and first name |
# | **Text Index** | Creates a full-text search index on string content | Enables searching for words/phrases within text fields | When implementing search functionality across text content | `db.articles.createIndex({ title: "text", content: "text" })` - Search articles by keywords |
#
# <table style="width:100%; border-collapse: collapse;">
#   <tr>
#     <td style="padding: 18px; vertical-align: top; font-size: 15px; line-height: 1.6;">
#       🔸 When there is no index, MongoDB performs a <strong>COLLSCAN (Collection Scan)</strong> — it checks every document one by one, which is slow for large collections.
#       <h3 style="margin-top: 20px;">⚙️ How Indexing Works Internally</h3>
#       <ul>
#         <li>MongoDB stores indexes using the <strong>B-tree (Balanced Tree)</strong> data structure.</li>
#         <li>B-trees store <strong>index keys</strong> along with <strong>pointers to the actual documents</strong> in the collection.</li>
#         <li>The structure allows fast traversal, insertions, deletions, and range-based queries.</li>
#       </ul>
#     </td>
#     <td style="text-align: center; padding: 20px;">
#       <img src="../images/picsiee.png" alt="MongoDB Indexing" style="width: 500px; border: 1px solid #ccc;"/>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### (i) Single Field Index
# - A single-field index is created on one field of a collection and is useful when your queries frequently filter or sort by that field.
# - Suppose we often search for books by their author. Without an index, MongoDB would scan every document (collection scan), while with the index on author, it can jump directly to matching entries

# %%
# creates an ascending index on the author field. 
db.books.create_index({"author": 1})    # 1 = ascending order
# Queries like below will now be faster:
db.books.find({"author": "Dr. Arif"})

# %% [markdown]
# ### (ii) Compound Index
# - A compound index includes multiple fields in a single index, and is useful when queries involve filtering or sorting on more than one field.
# - Suppose we often search for books by both author and price. Without an index, MongoDB would scan every document (collection scan), while with the index on author and price, it can jump directly to matching entries
# - Order matters in compound indexes — {author: 1, price: -1} is different from {price: -1, author: 1}. Design them based on the most common query patterns.

# %%
# creates an index sorted by author (ascending) and then by price (descending).
db.books.create_index({"author": 1, "price": -1})
# Queries like below will now be faster:
db.books.find({"author": "Dr. Arif"}).sort("price", -1)

# %% [markdown]
# ### (iii) Text Index
# - A text index allows full-text search on string fields (like searching words in titles or comments), and is useful when you want to support keyword searches.
# - MongoDB’s text index tokenizes and normalizes words to enable keyword searching.
# - It supports operators like `$search`, `$language`, and `$caseSensitive`.

# %%
# enable keyword search in book titles or review comments:
# On the books collection
db.books.create_index({"title": "text"})
# On the reviews collection (for multiple fields)
db.reviews.create_index({"comment": "text", "book": "text"})

# Now you can perform full-text searches like:
db.books.find({"$text": {"$search": "MongoDB"}})
db.reviews.find({"$text": {"$search": "Excellent"}})

# %%
# List all indexes on books collection
for index in db.books.list_indexes():
    print(index)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('author', 1)])), ('name', 'author_1')])
# SON([('v', 2), ('key', SON([('author', 1), ('price', -1)])), ('name', 'author_1_price_-1')])
# SON([('v', 2), ('key', SON([('_fts', 'text'), ('_ftsx', 1)])), ('name', 'title_text'), ('weights', SON([('title', 1)])), ('default_language', 'english'), ('language_override', 'language'), ('textIndexVersion', 3)])

# %%
# List all indexes on reviews collection
for index in db.reviews.list_indexes():
    print(index)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('_fts', 'text'), ('_ftsx', 1)])), ('name', 'comment_text_book_text'), ('weights', SON([('book', 1), ('comment', 1)])), ('default_language', 'english'), ('language_override', 'language'), ('textIndexVersion', 3)])

# %%
# Drop a specific index by name from reviews collection
db.reviews.drop_index("comment_text_book_text")

# List all indexes on reviews collection
for index in db.reviews.list_indexes():
    print(index)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])

# %%
# Drop all indexes from books collection
db.books.drop_indexes()

# List all indexes on books collection
for index in db.books.list_indexes():
    print(index)
# Out:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])

# %% [markdown]
# # Close connection

# %%
client.close()
print("\n✓ Connection closed successfully!")
# Drop Entire Database
#db.dropDatabase();
# Out:
# ✓ Connection closed successfully!

# %% [markdown]
# # <span style='background :lightgreen' >5. Cloud-Hosted MongoDB: `MongoDB Atlas`</span>
# - If you don't want to install MongoDB locally, you can use **MongoDB Atlas** (a cloud-hosted MongoDB database service) managed by MongoDB Inc. on cloud providers (AWS, Azure, Google Cloud)
# - MongoDB Atlas provides automated backups, scaling, replication, security and monitoring with NO server management needed
# - To get started:
#   1. Create a free account at https://www.mongodb.com/cloud/atlas
#   2. Create a free cluster (M0 tier)
#   3. Get your connection string
#   4. Access MongoDB Atlas via its web UI at https://cloud.mongodb.com
# - You can also manage Atlas from the command line by installing **MongoDB Atlas CLI**, using: `brew install mongodb-atlas-cli`
# - **MongoDB Atlas CLI** is a command-line interface tool that lets you manage MongoDB Atlas (cloud databases) directly from your terminal, without using the web browser. Its key features are:
#   - Create, configure, and manage Atlas clusters
#   - Deploy databases and configure settings
#   - Manage users, security, and access controls
#   - Monitor database performance and logs
#   - Automate deployments and CI/CD pipelines
# - You can connect directly to your MongoDB Atlas cluster using the MongoDB Shell (`mongosh`), by providing the connection string that contains all the information needed to connect to your cloud database. This is used to execute database queries and operations. Follow the steps mentioned below to get the connection string conatining <username>, <password>, <clusterhostname> and <database> preceded by the Protocol using DNS seedlist for automatic server discovery:
#     - Log in to MongoDB Atlas web UI
#     - Click "Connect" on your cluster
#     - Choose "Connect with MongoDB Shell"
#     - Copy the provided connection string
# ```bash
# $ mongosh "mongodb+srv://username:password@cluster0.xxxxx.mongodb.net/myDatabase"
# # You're now connected and can run MongoDB commands
# $ show dbs
# ```
# - In order to manage MongoDB Atlas infrastructure and resources from the command line you can use `Atlas CLI`, which focuses on cluster management, configuration, and administration (not direct database queries)
# ```bash
# # Login to Atlas using following command. For the first time only it  will open your web browser for authentication, link your terminal to your Atlas account, creates an API key for subsequent commands. Only needs to be done once (credentials are saved)
# $ atlas auth login
# # Following command will display  all MongoDB clusters (cluster names, regions, tiers (M0, M10, etc.), and status) in your Atlas project
# $ atlas clusters list
# ```

# %% [markdown]
# ### What is MongoDB Atlas:
# - If you don't want to install MongoDB locally, you can use **MongoDB Atlas** (a cloud-hosted MongoDB database service) managed by MongoDB Inc. on cloud providers (AWS, Azure, Google Cloud)
# - MongoDB Atlas provides automated backups, scaling, replication, security and monitoring with **NO server management needed**
# - Get a free M0 cluster with 512 MB storage - perfect for learning and small projects
# ### How to get started:
# - Create a free account at https://www.mongodb.com/cloud/atlas
# - https://www.mongodb.com/cloud/atlas/register
# - Create a free cluster (M0 tier - free forever)
# - Set up database access by creating a database user with username and password
# - Configure network access by adding your IP address to the whitelist (or allow access from anywhere: `0.0.0.0/0`)
# - Access MongoDB Atlas via its web UI at https://cloud.mongodb.com
# ### Connecting via mongosh:
# - You can connect directly to your MongoDB Atlas cluster using the MongoDB Shell (`mongosh`)
# - Use a connection string that contains all the information needed to connect to your cloud database
# - **How to get your connection string:**
#   1. Log in to MongoDB Atlas web UI
#   2. Click "Connect" on your cluster
#   3. Choose "Connect with MongoDB Shell"
#   4. Copy the provided connection string
#   5. Replace `<username>`, `<password>`, `<clusterhostname>`, and `<database>` with your actual values
# - **Connection string format:**
#   ```
#   mongodb+srv://username:password@cluster0.xxxxx.mongodb.net/myDatabase
#   ```
#   - `mongodb+srv://` - Protocol using DNS seedlist for automatic server discovery
#   - `username:password` - Your Atlas database credentials
#   - `cluster0.xxxxx.mongodb.net` - Your cluster hostname
#   - `myDatabase` - The specific database (optional)
# - **Example:**
#   ```bash
#   $ mongosh "mongodb+srv://student:pass123@cluster0.abc12.mongodb.net/schoolDB"
#   $ show dbs  # You're now connected and can run MongoDB commands
#   ```
# ### MongoDB Atlas CLI:
# - You can also manage Atlas from the command line by installing **MongoDB Atlas CLI**
# - **Install:** `brew install mongodb-atlas-cli`
# - **MongoDB Atlas CLI** is a command-line interface tool that lets you manage MongoDB Atlas (cloud databases) directly from your terminal, without using the web browser
# - It focuses on cluster management, configuration, and administration (not direct database queries)
# - **Key features:**
#   - Create, configure, and manage Atlas clusters
#   - Deploy databases and configure settings
#   - Manage users, security, and access controls
#   - Monitor database performance and logs
#   - Automate deployments and CI/CD pipelines
# - **Basic commands:**
#   ```bash
#   # Login to Atlas (first time only)
#   $ atlas auth login
#   ```
#   > Opens your web browser for authentication, links your terminal to your Atlas account, creates an API key for subsequent commands. Only needs to be done once (credentials are saved)
#   ```bash
#   # List all clusters
#   $ atlas clusters list
#   ```
#   > Displays all MongoDB clusters (cluster names, regions, tiers (M0, M10, etc.), and status) in your Atlas project
# ### Connecting via MongoDB Compass:
# - Open MongoDB Compass application
# - Paste your Atlas connection string in the connection field
# - Click **Connect** to access your cloud database with a visual interface
# ### Atlas web UI features:
# - **Cluster management:** Create, pause, resume, and delete clusters
# - **Data explorer:** Browse and query your data directly in the browser
# - **Performance advisor:** Get index recommendations and query optimization suggestions
# - **Charts:** Create visualizations and dashboards from your MongoDB data
# - **Monitoring:** Real-time performance metrics, alerts, and query profiling
# - **Triggers:** Set up database triggers to execute functions on data changes
# - **App Services:** Build serverless applications with Atlas App Services
# ```

# %% [markdown]
# # <span style='background :lightgreen' >To Do: Database Replication vs Database Sharding</span>
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px"><b>Sharding</b> is the process of distributing data across multiple servers (called shards) to support horizontal scaling.  It's used when your data set becomes too large to fit on a single machine or when you need high throughput for reads and writes.</div></h3>
#
# - Watch:
#     -  [Mongo DB Sharding Basics!](https://www.youtube.com/watch?v=ooF021_Kbck)
#     -  [Replication vs Sharding](https://www.youtube.com/watch?v=jLEp1XI_L6Q)
#
#
# ## Why Use Sharding?
#
# - **Scalability**: Add more machines to handle more data.
# - **Performance**: Queries and writes can be distributed.
# - **Storage Distribution**: Splits large datasets across shards.
