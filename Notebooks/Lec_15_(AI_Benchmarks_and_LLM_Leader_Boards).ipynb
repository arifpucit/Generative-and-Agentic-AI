# %% [markdown]
# ---
#  <img align="left" width="75" height="75"  src="https://upload.wikimedia.org/wikipedia/en/c/c8/University_of_the_Punjab_logo.png">
#
# <h1 align="center">Department of Data Science</h1>
#
# ---
# <h3><div align="right">Instructor: Muhammad Arif Butt, Ph.D.</div></h3>

# %% [markdown]
# <h1 align="center">Lec-15: AI Benchmarks and LLM Leader Boards</h1>

# %% [markdown]
# # Learning agenda of this notebook
# 1. How to Choose one LLM out of many?
# 2. Evaluating Basic Attributes For Models
#     - Open vs. Closed Source
#     - Release Date & Knowledge Cutoff
#     - Model Size & Parameters
#     - Training Data Size
#     - Size of Context Window
#     - Cost Considerations
#     -  Performance & Practical Factors
# 3. The Chinchilla Scaling Law
# 4. LLM Evaluation Metrics
# 5. What are AI Benchmarks for LLMs?
# 6. Some Famous LLM Evaluation Benchmarks
# 7. What are LLM Leaderboards?
# 8. Examples of LLM Leaderboards
#     - Open LLM Leaderboard
#     - Vellum AI Leaderboard
#     - Chatbot Arena Leaderboard
#     - Scale AI SEAL Leaderboard
#     - LLM Stats Leaderboard
#     - BigCode Models Leaderboard
#     - LLM Performance Leaderboard

# %% [markdown]
# **[A Comprehensive Guide on Hugging Face Training and Benchmark Datasets:](https://www.cs.virginia.edu/~rmw7my/Courses/AgenticAISpring2026/datasets2025.html)**

# %% [markdown]
# # <span style='background :lightgreen' >1. How to Choose one LLM out of many?</span>
# <h2 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">The best AI model is the one that solves YOUR problem!</div></h2>
#
# ## Basic Idea
# - **Think of AI models like cars - there's no single "best" car for everyone!**
#     - A sports car is great for speed, but terrible for moving furniture
#     - A truck is perfect for heavy work, but uses more fuel
# - Same with AI models - pick the one that fits YOUR job!
# - **The process is simple:**
#     - **Look at basic features** (like checking a car's specs)
#     - **Compare performance** (like reading car reviews)
#     - **Test drive your favorites** (try them out!)

# %% [markdown]
# ## Two Ways to Compare Models
# #### Method 1: Basic Facts & Attributes
# - Like checking a car's basic info before you even visit the dealer:
#     - Price range
#     - Size
#     - Fuel type
#     - Year made
# #### Method 2: Detailed Results
# - Like reading detailed car reviews and test results:
#     - How fast does it go?
#     - How reliable is it?
#     - What do other users say?

# %% [markdown]
# # <span style='background :lightgreen' >2. Evaluating Basic Attributes For Models</span>
#
# ## a. Open vs. Closed Source (Think of this like owning or renting a car)
# - **Open Source:**
#   - You can modify it however you want
#   - You pay once, use forever
#   - But YOU have to maintain it
#   - Example Models:
#     - Meta's LLaMA 3.2, Code LLaMA, LLaMA 4 (Scout, Maverick, Behemoth)
#     - Google DeepMind's Gemma 2B, Gemma 7B and Gemma-Instruct
#     - DeepSeek's DeepSeek-V3, DeepSeek-Code, DeepSeek-Lite
#     - Microsoft's Phi-1, Phi-2, Phi-3, Phi-3-mini
#     - Alibaba's Qwen-7B/14B/72B, Qwen-VL, Qwen-Audio
#     - Mistral 7B and Mixtral 8x7B
# - **Closed Source:**
#   - Someone else handles all the maintenance
#   - You pay monthly/yearly
#   - But you can't modify it much
#   - Example Models:
#       - OpenAI's GPT-3.5, GPT-4 and GPT-4-Turbo, GPT-4o-mini, GPT-4o, GPT-4o + Canvas, GPT-5
#       - Anthropic's Claude Opus, Claude Sonnet, Claude Haiku
#       - Google DeepMind's Gemini Ultra, Gemini Pro, Gemini Nano, Gemini Flash
#       - Cohere's Command models

# %% [markdown]
# ## b. Release Date & Knowledge Cutoff (Think of this like a car's model year)
# - **Release Date**: When was this AI model "built"?
# - **Knowledge Cutoff**: What's the latest information it knows?
# - **Example**: An AI from 2022 won't know about events from 2024
# - **Important for**: News, current events, recent discoveries
# - **Pro tip**: Always check the knowledge cutoff date before choosing a model for time-sensitive tasks

# %% [markdown]
# ## c. Model Size & Parameters (Think of this like a car's engine size)
# - **More parameters = Bigger, more powerful engine**
# - **Bigger engines**:
#   - Can handle harder tasks
#   - Use more fuel (cost more to run)
#   - Need more space (computing power)
#
# **Simple rule**: Bigger = smarter but more expensive
#
# **Common parameter ranges**:
# - **Very Small models**: < 1B parameters (Research purpose)
# - **Small models**: 1B-13B parameters (fast, affordable)
# - **Medium models**: 13B-70B parameters (balanced performance)
# - **Large models**: 100B+ parameters (highest quality, most expensive)

# %% [markdown]
# ## d. Training Data Size (Think of this like how much driving experience someone has)
# - **More training data = More experienced driver**
# - **An AI trained on more text**:
#   - Knows more topics
#   - Gives better answers
#   - Understands context better
#
# **Data quality matters too**: A model trained on high-quality, curated data often performs better than one trained on more but lower-quality data.

# %% [markdown]
# ## e. Size of Context Window (Think of this like how much you can fit in a car's trunk)
# - **Context = How much text the AI can "remember" at once**
# - **Includes**: Your question + examples + chat history
# - **Example**: Some AIs can remember entire books (1M+ words)
# - **Important for**: Long documents, detailed conversations
#
# **Context length ranges**:
# - **Short**: 4K-8K tokens (good for simple tasks)
# - **Medium**: 32K-128K tokens (handles most documents)
# - **Long**: 1M+ tokens (entire books, massive codebases)

# %% [markdown]
# ## f. Cost Considerations
# #### (i) Inference Costs (This is like fuel costs for your car)
# - **API costs**: Pay per use (like paying per mile)
#   - Usually measured in cost per 1K tokens
#   - Input tokens often cheaper than output tokens
# - **Subscription fees**: Monthly payment (like a bus pass)
# - **Compute costs**: Running it yourself (like owning and fueling your car)
# - **Cost optimization tips**:
#     - Use smaller models for simple tasks
#     - Batch requests when possible
#     - Consider prompt engineering to reduce token usage
#
#
# #### (ii) Training Costs (This is like customizing your car)
# - **Only applies if you want to "teach" the AI new tricks**
# - **Most people DON'T need this** - like most people don't modify their car engine
# - **Pre-made AIs** (like ChatGPT) have NO training cost
# - **Fine-tuning**: Cheaper alternative to full training for specific use cases
#
#
# #### (iii) Build cost & Time to MarketTraining Costs (This is like "how quickly can I start using this?)
# - **Ready-made AIs** (like ChatGPT):
#   - Start using immediately
#   - No setup required
#   - Works right out of the box
# - **Build-your-own AIs**:
#   - Takes weeks/months to set up
#   - Need technical expertise
#   - More work, but more control

# %% [markdown]
# ## g. Performance & Practical Factors
# #### (i) Rate Limits & Reliability (Think of this like traffic rules and road conditions)
# - **Rate Limits**: "You can only ask 100 questions per hour"
# - **Reliability**: "Will this AI work when I need it?"
# - **Some AIs get busy** (like traffic jams) and slow down
# - **Check for**:
#     - Requests per minute/hour limits
#     - Uptime guarantees (SLA)
#     - Geographic availability
# #### (ii) Speed vs. Latency (Think of this like two different types of "fast")
# - **Speed**: How fast does it talk once it starts?
#   - Like how fast a car goes on the highway
#   - Measured in tokens per second
# - **Latency**: How long before it starts talking?
#   - Like how long it takes to start your car
#   - Measured in milliseconds to first token
# - **For real-time apps** (like chatbots), latency matters more!
# #### (iii) Licensing (Think of this like the rules for using a rental car)
# - **Can you use it for business?**
# - **Can you let others use it?**
# - **Are there restrictions?**
# - **Common license types**:
#     - **Commercial licenses**: Full business use allowed
#     - **Research licenses**: Academic/research use only
#     - **Custom licenses**: Specific terms negotiated
# #### (iv) Specialized Capabilities (Consider what specific skills you need)
# - **Code generation**: Models like Code Llama, GitHub Copilot
# - **Multilingual support**: Models trained on diverse languages
# - **Mathematical reasoning**: Models with strong STEM (Science, Technology, Engineering, and Mathematics) performance
# - **Creative writing**: Models optimized for storytelling and content creation
# - **Function calling**: Models that can interact with external tools and APIs
# ### Finally Ask yourself these questions:
# 1. **What's my budget?** (Free, pay-per-use, or enterprise)
# 2. **What's my use case?** (Chatbot, content creation, code analysis, cybersecurity)
# 3. **How much control do I need?** (Plug-and-play vs. customizable)
# 4. **How fast do I need responses?** (Real-time vs. batch processing)
# 5. **What's my technical expertise?** (Beginner vs. advanced developer)

# %% [markdown]
# <img src="../images/1.png" alt="Chinchilla Scaling Law"
#      style="float: right; width: 800px; margin-left: 10px; border-radius: 8px;">
#
# # <span style='background :lightgreen' >3. The Chinchilla Scaling Law (Model Size vs Training Data)</span>
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">For optimal training efficiency, LLMs should use approximately 20 training tokens for every modal parameter</div></h3>
#
#
# - The Chinchilla Scaling Law is like a **cooking recipe for AI models**, that tells you the perfect balance between two main ingredients:
#     - **Model Size** (parameters) = How big the AI's "brain" is
#     - **Training Data** (tokens) = How much text you feed it to learn
# ### The Student Brain Analogy
# - Think of it like training students in school:
#     - **Parameters** = The size of a student's brain (their capacity to learn)
#     - **Training Data** = The number of books they read (the knowledge they consume)
# ### The Mathematical Rule (The Secret Recipe)
# ```
# Count of Optimal Modal Parameters = Training Tokens ÷ 20
# ```
# **Perfect Training (Following Chinchilla):**
# - 1B parameters → 1B × 20 = 20B tokens
# - 7B parameters → 7B × 20 = 140B tokens
# - 70B parameters → 70B × 20 = 1.4T tokens
# > **If you double the model size → you should double the training data**
# ### Before Chinchilla Law (The Old Way):
# - **Companies thought**: "Bigger model = automatically better AI", so what they did was:
#     - Made huge models with lots of parameters
#     - Didn't give them enough training data
#     - Wasted tons of money and computing power
# - **Result**: Expensive, inefficient AIs that weren't as good as they could be
# ### After Chinchilla Law (The Smart Way):
# - **Companies realized**: that they need to balance BOTH size AND data, so what they do now is:
#     - Calculate the optimal model size for their data
#     - Or calculate the optimal data amount for their model size
#     - Make smarter decisions about resource allocation
# **Result**: More efficient, powerful AIs for less money
#
# ### [Read: Training Compute-Optimal Large Language Models](https://arxiv.org/pdf/2203.15556)
# - The Chinchilla Scaling Law was developed by **Jordan Hoffmann** and **21** other authors at **Google DeepMind**, presented in March **2022** in their paper **Training Compute-Optimal Large Language Models**, publically available at this link: https://arxiv.org/pdf/2203.15556
# - Jordan discovered that most existing models (like GPT-3) were "over-parameterized" and "under-trained" - meaning they had too many parameters relative to their training data, making them compute-inefficient.

# %% [markdown]
# # <span style='background :lightgreen' >4. LLM Evaluation Metrics</span>
# ## a. Why LLM Evaluation Matters?
#
# ### How Traditional ML/DL Models Were Evaluated?
# - Before Large Language Models, evaluation in machine learning and deep learning was relatively straightforward because models solved well-defined, closed-ended tasks with clear right or wrong answers. The evaluation process relied on a fixed set of numerical metrics applied to a held-out test dataset:
#     - **Classification models** (e.g., spam detection, image recognition) were evaluated using Accuracy, Precision, Recall, F1 Score, and AUC-ROC — all computed by comparing predicted labels against known ground truth labels.
#     - **Regression models** (e.g., house price prediction) were evaluated using Mean Squared Error (MSE), Mean Absolute Error (MAE), and R² Score — measuring how close the predicted number was to the actual number.
#     - **Deep learning models** (e.g., CNNs for image classification, RNNs for time-series) used the same label-based metrics, with training and validation loss curves used to detect overfitting or underfitting during training.
# - The key characteristic of traditional evaluation was that it was fully automated, objective, and scalar — a single number (like 94% accuracy) could summarize model performance. Ground truth was always available, outputs were always comparable, and evaluation required no human judgment.
#
# ### Why LLMs Break the Traditional Evaluation Mold?
# - LLMs are fundamentally different because they generate **free-form, open-ended text** rather than a fixed label or number. This breaks every assumption that made traditional evaluation simple:
# | Traditional ML/DL | Large Language Models |
# |---|---|
# | Output is a label or number | Output is free-form text of arbitrary length |
# | One correct answer exists | Many valid answers can exist for the same question |
# | Evaluation is fully automated | Often requires human judgment or another LLM to evaluate |
# | A single metric (e.g., accuracy) is sufficient | Multiple dimensions must be evaluated simultaneously |
# | Ground truth is always available | Ground truth is often unavailable or subjective |
# - For example, asking a model *"Explain how a transformer works"* can produce dozens of equally valid responses — there is no single correct answer to match against, so accuracy alone is meaningless.
#
# ### Why Rigorous LLM Evaluation Still Matters?
# - Despite this complexity, evaluation remains essential:
#     - **High-stakes deployment:** Modern LLMs are used in healthcare, finance, education, and legal domains where a hallucinated fact or a biased output can cause real-world harm.
#     - **Multi-dimensional quality:** A good LLM response must simultaneously be factually accurate, logically coherent, faithful to its source, relevant to the question asked, and free of harmful content — no single metric captures all of this.
#     - **Preventing hallucinations:** Without systematic evaluation, fabricated but confident-sounding outputs go undetected and erode user trust.
#     - **Continuous improvement:** Evaluation drives model selection, prompt optimization, and fine-tuning — ensuring AI systems keep improving and stay aligned with human intent.

# %% [markdown]
# ## b. Core Evaluation Metrics
#
# | # | Metric | Core Question | Key Method | Common Pitfall |
# |---|--------|--------------|------------|----------------|
# | 1 | Accuracy | Is the answer factually correct? | Compare output against expert-validated ground truth answers | Hard to apply when no verified reference dataset exists |
# | 2 | Coherence | Is the response logically structured and easy to follow? | Scored by human graders or an LLM judge using a clarity rubric | Scores can differ across reviewers since clarity is partly subjective |
# | 3 | Faithfulness | Does the output only say what the source material supports? | Claim-by-claim verification using Retrieval Augmented Generation Assessment (RAGAS) | Cannot be measured without access to the original source documents |
# | 4 | Answer Relevance | Does the response actually address what the user asked? | Generate questions from the output and check if they match the original query | A response can be accurate and well-written yet still miss the user's real intent |
# | 5 | Hallucination Detection | Did the model invent facts that were never in the source? | [SelfCheckGPT](https://arxiv.org/abs/2303.08896) consistency testing and Natural Language Inference (NLI) entailment checks | Confident-sounding language makes fabricated claims hard to spot without verification |
# | 6 | Toxicity & Safety | Does the output contain harmful, biased, or offensive content? | Automated toxicity classifiers combined with adversarial red-team testing | What counts as harmful varies across cultures, so a single classifier may over- or under-flag content |
# | 7 | Human-in-the-Loop (HITL) Evaluation | Would a qualified human reviewer consider this output acceptable? | Structured rubric-based review covering quality, tone, accuracy, and ethical concerns | Reviewer fatigue and personal bias can quietly degrade evaluation quality at scale |

# %% [markdown]
# ### Metric 1 — Accuracy (Correctness)
# - **What it measures:** Whether the model's output matches verified, real-world facts.
# - **Why it matters:** In high-stakes fields like healthcare, law, or finance, a single incorrect fact can cause serious harm.
# - **How it's evaluated:**
#     - Compare against expert-validated answers
#     - Semantic similarity using embeddings
#     - LLM-as-judge with rubric-based scoring
#     - Fact-checking via APIs and knowledge bases
#     - F1 score (precision + recall)
# - **Best use cases:** QA systems, diagnostic assistance, financial reporting
# - **⚠️ Limitations:**
#     - Requires high-quality ground truth data
#     - May miss partially correct answers
#     - Computationally expensive at scale

# %% [markdown]
# ### Metric 2 — Coherence
# - **What it measures:** Logical flow, clarity, and internal consistency of the response.
# - **Why it matters:** Great ideas mean nothing if they're presented in a confusing or jumbled way. This is especially critical in education and long-form writing.
# - **How it's evaluated:**
#     - Human graders assess clarity and structure
#     - LLM-as-judge analysis
#     - Self-consistency across multiple outputs
#     - Linguistic and grammatical checks
# - **Best use cases:** Storytelling, explanations, reports, instructional content
# - **⚠️ Limitations:**
#     - Somewhat subjective
#     - Hard to automate perfectly
#     - Can vary across different audiences

# %% [markdown]
# ### Metric 3 — Faithfulness (Groundedness)
# - **What it measures:** Whether the output stays true to the source material without adding unsupported claims.
# - **Why it matters:** A model that adds "facts" not found in the source is hallucinating; even if it sounds confident. This is the core metric for RAG systems.
# - **How it's evaluated:**
#     - Verify claims against the source text
#     - RAGAS faithfulness score
#     - Reverse question generation (QAG)
#     - Attribution mapping to source passages
#     - Uncertainty detection when evidence is weak
# - **Best use cases:** RAG pipelines, summarization, research assistants
# - **⚠️ Limitations:**
#     - Requires access to source documents
#     - Expensive for long contexts
#     - Difficult with implicit or indirect information

# %% [markdown]
# ### Metric 4 — Answer Relevance
# - **What it measures:** How well the output actually addresses what the user asked.
# - **Why it matters:** A response can be accurate but still miss the point entirely. An off-topic answer wastes the user's time and erodes trust.
# - **How it's evaluated:**
#     - Reverse question generation
#     - Relevance scoring (% of on-topic statements)
#     - LLM-based relevance judging
#     - Semantic intent matching
# - **Best use cases:** Chatbots, search engines, customer support, QA
# - **⚠️ Limitations:**
#     - Relevance can be subjective
#     - May overlook partial relevance
#     - Depends on correct intent interpretation

# %% [markdown]
# ### Metric 5 — Hallucination Detection
# - **What it measures:** Whether the model fabricated information that was never in the source or doesn't exist in reality.
# - **Why it matters:** Hallucinations are the #1 trust-breaker in AI — the model sounds authoritative while being completely wrong.
# - **How it's evaluated:**
#     - Extract and verify individual claims
#     - SelfCheckGPT: sample multiple outputs and check consistency
#     - Dedicated hallucination detectors (e.g., Lynx)
#     - Entailment checks using NLI models
#     - Frequency analysis across sampled outputs
# - **Best use cases:** Safety-critical systems, RAG, legal and medical tools
# - **⚠️ Limitations:**
#     - May flag correct reasoning as false positive
#     - Expensive for long texts
#     - Can miss subtle hallucinations

# %% [markdown]
# ### Metric 6 — Toxicity & Safety
# - **What it measures:** Whether the output contains harmful, biased, or inappropriate content.
# - **Why it matters:** AI deployed to the public must never produce dangerous, hateful, or irresponsible outputs — especially in open-ended conversational settings.
# - **How it's evaluated:**
#     - Toxicity classifiers
#     - DeepEval toxicity scoring
#     - Bias and stereotype detection
#     - Red-team adversarial testing
#     - Policy compliance checks
# - **Best use cases:** Public chatbots, social platforms, content moderation
# - **⚠️ Limitations:**
#     - Cultural sensitivity varies across regions
#     - Possible false positives
#     - Can be bypassed with adversarial prompts

# %% [markdown]
# ### Metric 7 — Human-in-the-Loop (HITL) Evaluation
# - **What it measures:** Quality of AI outputs as assessed by human reviewers, combining machine speed with human judgment.
# - **Why it matters:** Some decisions are too important or nuanced to leave entirely to an algorithm — humans catch ethical issues, subtle biases, and edge cases that automated metrics miss.
# - **How it's evaluated:**
#     - Human review for errors, biases, and ethical concerns
#     - Structured rubric-based rating and ranking
#     - Annotation and correction of inaccurate responses
#     - Preference learning to train RLHF models
#     - Scenario testing for edge cases and adversarial prompts
#     - Feedback integration to continuously fine-tune models
# - **Best use cases:** Healthcare, law, finance, content moderation, AI governance
# - **⚠️ Limitations:**
#     - Time-consuming and expensive at scale
#     - Evaluator subjectivity and potential bias
#     - Reviewer fatigue can affect quality over time
#     - Requires diverse and skilled human reviewers

# %% [markdown]
# # <span style='background :lightgreen' >5. What are AI Benchmarks for LLMs?</span>
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">Standardized evaluation frameworks that test how well a model performs on tasks such as language understanding, text generation, summarization, translation, coding, reasoning, math problem solving, knowledge retrieval, and multi-modal comprehension. They rely on fixed datasets and clear metrics to ensure fair and consistent comparisons between models.</div></h3>
#
# ### How AI Benchmarks works:
# - All AI models (GPT-4, Claude, Gemini, etc.) take the same "tests" (benchmarks)
# - They get scored on each benchmark
# - We can then compare which model is "smarter" in different areas
# ### Example:
# - Model A might score 85% in General Knowledge and 75% in Math and 90% in Coding
# - Model B might score 70% in General Knowledge and 65% in Math and 95% in Coding
# - Model C might score 90% in General Knowledge and 45% in Math and 70% in Coding
# ### Why this matters:
# - **Researchers** use these scores to improve their models
# - **Companies** use them to show their AI is better than competitors
# - **Users** can choose which AI is best for their needs
# - **Students/Teachers** can understand AI capabilities objectively

# %% [markdown]
# # <span style='background :lightgreen' >6. Some Famous LLM Evaluation Benchmarks</span>
#
# - **General Reasoning**: Tests logical thinking and common sense
# - **Mathematical Reasoning**: Evaluates numerical problem-solving from grade school to competition level
# - **Coding**: Measures code generation across single and multiple programming languages
# - **Knowledge**: Assesses factual knowledge across academic and professional domains
# - **Safety & Truthfulness**: Evaluates reliability and resistance to misinformation
# - **NLP Fundamentals**: Tests core language understanding capabilities
# - **Human Preference**: Captures real-world user satisfaction through voting
#
# | **Category** | **Benchmark** | **What's Being Evaluated** | **Simple Description** | **Official / Reference Links** |
# |--------------|----------------|-----------------------------|-------------------------|--------------------------------|
# | **General Reasoning & Comprehension** | **ARC (AI2 Reasoning Challenge)** | Scientific Reasoning | Tests ability to answer grade-school science questions requiring reasoning beyond simple fact recall. Contains Challenge Set (hard questions) and Easy Set. | 1. https://arxiv.org/abs/1803.05457<br>2. https://allenai.org/data/arc<br>3. https://huggingface.co/datasets/allenai/ai2_arc |
# | **General Reasoning & Comprehension** | **DROP (Discrete Reasoning Over Paragraphs)** | Reading + Numerical Reasoning | Requires reading paragraphs and performing discrete operations like addition, counting, or sorting on numbers mentioned in the text. | 1. https://arxiv.org/abs/1903.00161<br>2. https://allenai.org/data/drop<br>3. https://huggingface.co/datasets/drop |
# | **General Reasoning & Comprehension** | **HellaSwag** | Commonsense Reasoning | Tests ability to select the most plausible continuation of everyday scenarios from multiple choices. Uses adversarial filtering to create challenging wrong answers. | 1. https://arxiv.org/abs/1905.07830<br>2. https://rowanzellers.com/hellaswag/<br>3. https://huggingface.co/datasets/Rowan/hellaswag |
# | **General Reasoning & Comprehension** | **IFEval (Instruction Following Evaluation)** | Instruction Following | Evaluates models on following specific, verifiable instructions like "write in exactly 400 words" or "mention keyword X at least 3 times." | 1. https://arxiv.org/abs/2311.07911<br>2. https://github.com/google-research/google-research/tree/master/instruction_following_eval<br>3. https://huggingface.co/datasets/google/IFEval |
# | **Mathematical Reasoning** | **GSM8K** | Grade-School Math | Contains 8,500 linguistically diverse math word problems requiring 2-8 steps of arithmetic reasoning to solve. | 1. https://arxiv.org/abs/2110.14168<br>2. https://github.com/openai/grade-school-math<br>3. https://huggingface.co/datasets/openai/gsm8k |
# | **Mathematical Reasoning** | **MATH Dataset** | Competition Mathematics | Features 12,500 challenging competition-level problems from AMC, AIME, and other math contests, with difficulty levels 1-5 and full step-by-step solutions. | 1. https://arxiv.org/abs/2103.03874<br>2. https://github.com/hendrycks/math<br>3. https://huggingface.co/datasets/hendrycks/competition_math |
# | **Coding & Software Engineering** | **HumanEval** | Python Code Generation | Contains 164 hand-written programming problems with function signatures, docstrings, and unit tests. Evaluated using pass@k metric measuring functional correctness. | 1. https://arxiv.org/abs/2107.03374<br>2. https://github.com/openai/human-eval<br>3. https://paperswithcode.com/dataset/humaneval |
# | **Coding & Software Engineering** | **MultiPL-E** | Multilingual Programming Language Evaluation | Extends HumanEval and MBPP benchmarks to 18+ programming languages including Java, C++, JavaScript, Rust, and more, enabling cross-language evaluation. | 1. https://arxiv.org/abs/2208.08227<br>2. https://github.com/nuprl/MultiPL-E<br>3. https://nuprl.github.io/MultiPL-E/ |
# | **Knowledge Exams & Academic Tests** | **MMLU (Massive Multitask Language Understanding)** | Multitask Knowledge (57 Subjects) | Evaluates knowledge across 57 subjects spanning STEM, humanities, social sciences, and professional domains using multiple-choice questions. | 1. https://arxiv.org/abs/2009.03300<br>2. https://github.com/hendrycks/test<br>3. https://huggingface.co/datasets/cais/mmlu |
# | **Knowledge Exams & Academic Tests** | **GPQA** | Graduate-Level Google-Proof Question Answering | Contains 448 extremely difficult, "Google-proof" questions in biology, physics, and chemistry. Domain experts achieve 65% accuracy; skilled non-experts with web access only reach 34%. | 1. https://arxiv.org/abs/2311.12022<br>2. https://github.com/idavidrein/gpqa<br>3. https://huggingface.co/datasets/Idavidrein/gpqa |
# | **Safety, Truthfulness & Robustness** | **TruthfulQA** | Truthfulness & Avoiding Misinformation | Contains 817 questions designed to test if models generate truthful answers or mimic common human misconceptions and falsehoods. Shows inverse scaling where larger models can be less truthful. | 1. https://arxiv.org/abs/2109.07958<br>2. https://github.com/sylinrl/TruthfulQA<br>3. https://huggingface.co/datasets/truthful_qa |
# | **Language Understanding (General NLP)** | **GLUE (General Language Understanding Evaluation)** | Core NLP Tasks | Tests fundamental language understanding through tasks like sentiment analysis, textual entailment, semantic similarity, and question answering across 9 diverse datasets. | 1. https://arxiv.org/abs/1804.07461<br>2. https://gluebenchmark.com/<br>3. https://huggingface.co/datasets/nyu-mll/glue |
# | **Chat & Conversation Quality** | **Chatbot Arena (LMSYS)** | Human Preference in Chat | Anonymous, randomized head-to-head battles where users vote for better responses. Uses Elo rating system to rank models based on crowdsourced human preferences from millions of votes. | 1. https://arxiv.org/abs/2403.04132<br>2. https://lmarena.ai/<br>3. https://huggingface.co/spaces/lmsys/chatbot-arena-leaderboard |

# %% [markdown]
# # <span style='background :lightgreen' >7. What are LLM Leaderboards?</span>
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">LLM leaderboards are ranking systems that compare and score different language models based on their performance across standardized benchmarks and evaluation tasks.</div></h3>
#
# ###  How to Find the Right Leaderboard
# ### By Task Type:
# - **General Language Tasks** → Open LLM Leaderboard
# - **Code Generation** → BigCode Models Leaderboard
# - **Chatbot Quality** → Chatbot Arena
# - **Performance Metrics** → LLM Performance Leaderboards
# - **Embeddings** → MTEB Leaderboard
# - **AI Agents** → GAIA Leaderboard
# - **Medical Domain** → Open Medical LLM Leaderboard
# ### By Benchmark:
# - **HumanEval/MultiPL-E** → BigCode Models Leaderboard
# - **MMLU** → Open LLM Leaderboard
# - **MTBench** → Chatbot Arena
# - **MTEB** → MTEB Leaderboard
# - **SWE-bench** → SWE-bench Leaderboard

# %% [markdown]
# # <span style='background :lightgreen' >8. Examples of LLM Leaderboards</span>

# %% [markdown]
# # (i) [Open LLM Leaderboard](https://huggingface.co/spaces/open-llm-leaderboard/open_llm_leaderboard#/)
# - Visit: https://huggingface.co/spaces/open-llm-leaderboard/open_llm_leaderboard#/
# - The Open LLM Leaderboard on Hugging Face is a powerful tool that shows how different AI models perform on various benchmarks tests. Think of it like a report card for AI models - it tells you which ones are smartest at different tasks!
# - The following screenshot shows:
#     - Models are ranked from best to worst (top to bottom)
#     - Each benchmark (IFEval, BBH, MATH, GPQA, MUSR, MMLU-PRO) has its own column
#     - Scores are shown as percentages (higher = better)
#     - Look at the Average column to see which models perform best overall
#     - Click on any specific benchmark column to see which models are best at that particular task
#     - Go to Column Visibility and Select which u want to see about Models
#     - Notice dates like "2024-11-11", "2025-01-17" showing how recently models were added
#     - Compare models side-by-side to see their strengths and weaknesses
#
#
# <p align="center">
#   <img src="../images/2.png" alt="Screenshot 1 - Basic Rankings">
# </p>
#
# ### Cick Advanced Filters to Customize Your View
# - **Precision Format** (Left Side):
#     - **bfloat16**: Standard precision format
#     - **float16**: Half precision (faster but less accurate)
#     - **4bit**: Very compressed models (fastest but least accurate)
# - **Model Type** (Left Side):
#     - **Pretrained**: Basic trained models
#     - **Fine-tuned**: Models trained for specific tasks
#     - **Chat**: Models designed for conversations
#     - **Merge**: Combined models
#     - **Multimodal**: Models that can handle text, images, etc.
# - **Parameters** (Top Right):
#     - **Slider**: Choose model size (7B to 140B parameters)
#     - **Bigger numbers** = More powerful but slower models
#     - **Smaller numbers** = Faster but less capable models
# <p align="center">
#   <img src="../images/4.png" alt="Screenshot 1 - Basic Rankings">
# </p>

# %% [markdown]
# # (ii) [Vellum AI LLM Leaderboard](https://www.vellum.ai/llm-leaderboard)
#
# Visit: https://www.vellum.ai/llm-leaderboard
#
# - A comprehensive comparison platform for the latest AI language models, tracking performance across key benchmarks like reasoning, math, coding, and tool use.
# - In my opinion, this is the best Leaderboard as of today for comparing most latest LLMS (CLosed+ Open Source).
# - Using Vellum, developers, researchers, and businesses choosing the right AI model for their projects based on performance, cost, and speed requirements.
# - It offers following features:
#     - Interactive model comparison tool
#     - Real pricing data (input/output costs per million tokens)
#     - Speed metrics (tokens per second, latency)
#     - Multiple benchmark categories
#     - Independent evaluations from Vellum and open-source community
#
# <p align="center">
#   <img src="../images/5.png" alt="Screenshot 1 - Basic Rankings">
# </p>
#
#
# ## WE can compare two individual models also
#
# <p align="center">
#   <img src="../images/6.png" alt="Screenshot 1 - Basic Rankings">
# </p>

# %% [markdown]
# # (iii) [Chatbot Arena Leaderboard](https://lmarena.ai/leaderboard)
# - Visit https://huggingface.co/spaces/lmarena-ai/chatbot-arena-leaderboard or https://lmarena.ai/leaderboard
# - The Chatbot Arena is a fantastic resource that focuses specifically on the instruct and chat use case - the ability of models to have conversations.
# - Rather than relying on benchmark tests, it uses human judgment to decide which model is better at instruction-following chats.
# - Humans can Vote for Models blindly ,you dont know about model names before voting, You just vote which one is giving result according to your preference or question and then you will get name of models
# - It's a qualitative decision where humans pick between Model A or Model B while chatting with both simultaneously. The key is it's a blind test - you don't know which model is which when voting.
# - **How the Ranking Works:**
#     - **Elo Rating System**: Models start with base ratings and gain/lose points based on battle outcomes. Higher Elo = more wins against other models.
#     - **Blind Testing**: Users chat with two anonymous models simultaneously and vote for the better response without knowing which is which.
#     - **Crowdsourced Evaluation**: Rankings come from 3.2M+ real user votes, not automated benchmarks, making them more representative of actual user preferences.
# - **Link for Testing voting : https://lmarena.ai/** The Arena lets you compare free open-source models against premium closed-source options. You can see if a free model like Llama or Mistral performs close enough to paid alternatives to justify the cost savings.
# <p align="center">
#   <img src="../images/arena.png" alt="Chatbot Arena">
# </p>

# %% [markdown]
# ## Do visit following:
#
# - **Collection of all leaderboards on HuggingFace:** https://huggingface.co/spaces?search=leaderboard
# - **BigCode Models Leaderboard:** https://huggingface.co/spaces/bigcode/bigcode-models-leaderboard
# - **BigCodeBench Leaderboard:** https://huggingface.co/spaces/bigcode/bigcodebench-leaderboard
# - **LiveCodeBench Leaderboard:** https://huggingface.co/spaces/livecodebench/leaderboard
# - **LLM Performance Leaderboard (Optimum):** https://huggingface.co/spaces/optimum/llm-perf-leaderboard
# - **LLM Performance Leaderboard (AI):** https://huggingface.co/spaces/ArtificialAnalysis/LLM-Performance-Leaderboard
# - **GAIA Leaderboard:** https://huggingface.co/spaces/gaia-benchmark/leaderboard
# - **WE-bench Leaderboard:** https://huggingface.co/spaces/princeton-nlp/SWE-bench-leaderboard
# - **Open VLM Leaderboard:** https://huggingface.co/spaces/opencompass/open_vlm_leaderboard
# - **LLM Arena:** https://lmarena.ai/

# %% [markdown]
# # AI Models Features, Capabilities & Limitations Comparison
#
# | Model | Context Window | Pricing Tier | Capabilities | Best Use Cases | Major Limitations |
# |-------|---------------|-------------|---------------|----------------|------------------|
# | **Claude Opus 4** | 1M tokens | Premium | • Hybrid reasoning architecture<br>• Superior complex problem solving<br>• Advanced coding & refactoring<br>• Step-by-step reasoning | • Complex software development<br>• Advanced research analysis<br>• Multi-step problem solving<br>• Large codebase analysis | • Higher cost<br>• Slower inference speed<br>• No real-time information |
# | **Claude Sonnet 4** | 1M tokens | Mid-tier | • Optimized speed-capability balance<br>• Enhanced coding abilities<br>• Efficient processing<br>• Good reasoning depth | • General development tasks<br>• Content creation<br>• Code review & debugging<br>• Daily productivity tasks | • Less capable than Opus 4 for complex reasoning<br>• No real-time information<br>• Limited multimodal capabilities |
# | **Claude Sonnet 3.7** | 200K tokens | Budget | • Cost-effective performance<br>• Solid reasoning engine<br>• Good general capabilities | • Basic coding assistance<br>• Content writing<br>• General Q&A<br>• Educational support | • Limited context length<br>• Superseded by newer models<br>• Reduced capabilities vs Claude 4 |
# | **Claude Sonnet 3.6** | 200K tokens | Budget | • Legacy support<br>• Basic language tasks | • Simple text generation<br>• Basic assistance tasks | • Outdated architecture<br>• Limited reasoning depth<br>• Poor coding capabilities |
# | **Claude Sonnet 3.5** | 200K tokens | Budget | • Earlier generation model<br>• Basic functionality | • Simple conversations<br>• Basic text tasks | • Significantly outdated<br>• Minimal reasoning abilities<br>• Very limited coding support |
# | **Claude Haiku 3.5** | 200K tokens | Economy | • Ultra-fast inference<br>• Cost-effective<br>• Lightweight processing | • Quick responses<br>• Simple Q&A<br>• Basic text processing<br>• High-volume applications | • Very limited reasoning<br>• Poor coding abilities<br>• Not suitable for complex tasks |
# | **Claude Opus 3** | 200K tokens | Legacy | • Previous flagship capabilities<br>• Advanced reasoning for its time | • Legacy system support<br>• Existing integrations | • Outdated vs Claude 4 series<br>• Limited context length<br>• Superseded architecture |
# | **GPT-4.5 Preview** | Unknown | Research | • Largest and best for chat<br>• Enhanced pre-training<br>• Advanced conversational AI | • Research applications<br>• Advanced conversations<br>• Prototype development | • Preview/beta status<br>• Limited availability<br>• Unverified stability<br>• Uncertain pricing |
# | **GPT-4.1** | 1M tokens | Premium | • Major coding improvements<br>• Enhanced instruction following<br>• Long-context understanding<br>• Reliable performance | • Professional development<br>• Complex coding projects<br>• Document analysis<br>• Business applications | • Training cutoff June 2024<br>• Premium pricing<br>• No real-time information<br>• Limited multimodal |
# | **GPT-4.0** | 32K-128K tokens | Standard | • Proven reliability<br>• Multimodal capabilities<br>• Established ecosystem | • General applications<br>• Multimodal tasks<br>• Established workflows | • Limited context length<br>• Outdated vs newer models<br>• Higher latency |
# | **Gemini 2.5 Pro** | 1M tokens (2M soon) | Premium | • Advanced multimodal processing<br>• Recent training data (Jan 2025)<br>• Excellent voice/video processing<br>• Current information access | • Multimodal applications<br>• Video/audio analysis<br>• Real-time information needs<br>• Creative multimodal projects | • Newer model with less track record<br>• Premium pricing<br>• Limited specialized domain expertise |
# | **Gemini 2.5 Flash** | 1M tokens | Mid-tier | • High-speed processing (636 tokens/s)<br>• Cost-optimized design<br>• Efficient multimodal<br>• Good general capabilities | • High-throughput applications<br>• Cost-conscious multimodal<br>• Fast response requirements<br>• Batch processing | • Reduced capabilities vs Pro<br>• Speed prioritized over depth<br>• Limited complex reasoning |
# | **Meta Llama 4 Maverick** | 256K tokens | Open-source | • Best-in-class multimodal<br>• 17B active/400B total parameters<br>• Native multimodal with early fusion<br>• Exceeds GPT-4o in coding/reasoning | • Advanced multimodal projects<br>• Open-source applications<br>• Custom fine-tuning<br>• Creative applications | • Requires significant compute<br>• Complex deployment<br>• Limited vs largest proprietary models |
# | **Alibaba Qwen3-235B** | 1M tokens | Variable | • Unique "thinking mode"<br>• 235B parameter architecture<br>• Competitive with US models<br>• Open-source availability | • Mathematical reasoning<br>• Complex problem solving<br>• Research applications<br>• Custom deployments | • Very high compute requirements<br>• Limited English documentation<br>• Regional deployment preferences |
# | **DeepSeek-R1** | 256K tokens | Budget | • Strong mathematical reasoning<br>• Excellent cost-performance ratio<br>• 90.8% MMLU score<br>• Accessible deployment | • Mathematical problems<br>• Educational applications<br>• Budget-conscious projects<br>• Reasoning-focused tasks | • Limited multimodal capabilities<br>• Focused primarily on reasoning<br>• Less general-purpose |
# | **Grok 3 Beta** | 128K tokens | Premium | • Leading reasoning (92.7% MMLU)<br>• Real-time information access<br>• Excellent mathematical reasoning<br>• Real-time trending topics | • Real-time analysis<br>• Current events research<br>• Mathematical problem solving<br>• Trend analysis | • Beta status limitations<br>• Limited general availability<br>• Potential stability issues<br>• Less established ecosystem |
#
# ## Capability Comparison Matrix
#
# | Model | Coding Excellence | Mathematical Reasoning | Multimodal Processing | Long Context Handling | Real-time Information | Cost Efficiency | Overall Rating |
# |-------|-------------------|------------------------|------------------------|------------------------|------------------------|------------------|----------------|
# | **Claude Opus 4** | ★★★★★ | ★★★★★ | ★★★ | ★★★★★ | ★★ | ★★ | ★★★★★ |
# | **Claude Sonnet 4** | ★★★★★ | ★★★★ | ★★★ | ★★★★★ | ★★ | ★★★ | ★★★★ |
# | **GPT-4.5 Preview** | ★★★★ | ★★★★ | ★★★★ | ★★★★ | ★★ | ★★ | ★★★★ |
# | **GPT-4.1** | ★★★★★ | ★★★★ | ★★★★ | ★★★★★ | ★★ | ★★ | ★★★★ |
# | **Gemini 2.5 Pro** | ★★★ | ★★★★ | ★★★★★ | ★★★★ | ★★★★ | ★★★ | ★★★★ |
# | **Gemini 2.5 Flash** | ★★★ | ★★★ | ★★★★ | ★★★★ | ★★★★ | ★★★★★ | ★★★ |
# | **Llama 4 Maverick** | ★★★★★ | ★★★★ | ★★★★★ | ★★★★ | ★★ | ★★★★★ | ★★★★ |
# | **Qwen3-235B** | ★★★★ | ★★★★★ | ★★★ | ★★★★ | ★★ | ★★ | ★★★ |
# | **DeepSeek-R1** | ★★★ | ★★★★★ | ★★ | ★★★ | ★★ | ★★★★★ | ★★★ |
# | **Grok 3 Beta** | ★★★★ | ★★★★★ | ★★★ | ★★★ | ★★★★★ | ★★ | ★★★★ |
